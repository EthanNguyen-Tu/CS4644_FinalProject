# %% [markdown]
# # CS 4644: Final Project Dataset Setup
#
# This notebook pulls the ["Human Faces" by Ashwin Gupta](https://www.kaggle.com/datasets/ashwingupta3012/human-faces/data), ["Fake-Vs-Real-Faces (Hard)" by Hamza Boulahi](https://www.kaggle.com/datasets/hamzaboulahia/hardfakevsrealfaces), and ["deepfake and real images" by Manjil Karki](https://www.kaggle.com/datasets/manjilkarki/deepfake-and-real-images) datasets from Kaggle and stores them in zip files to be easily loaded for our models.
#
# Copyright (c) 2025 Ethan Nguyen-Tu

# %% [markdown]
# ## Part 1: Setup

# %% [markdown]
# ##### STEP 1: Mount Google Drive for Google Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
drive_path = "drive/MyDrive" # NOTE: Separated so that colab can access the '.kaggle' folder in your Google Drive for Kaggle API authentication
project_folder = drive_path + "/CS4644_FinalProject"

# %% [markdown]
# ##### STEP 2: Basic Imports

# %%
import kagglehub
import os
import zipfile
import pandas as pd

# %% [markdown]
# ##### STEP 3: Package Installations (If Needed)

# %%
# ! pip install -q kaggle # Install kaggle if needed
! pip install imagehash
# Out:
# Collecting imagehash
#   Downloading ImageHash-4.3.2-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting PyWavelets (from imagehash)
#   Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from imagehash) (2.0.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from imagehash) (11.1.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from imagehash) (1.14.1)
# Downloading ImageHash-4.3.2-py2.py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 9.2 MB/s eta 0:00:00
# Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 74.3 MB/s eta 0:00:00
# Installing collected packages: PyWavelets, imagehash
# Successfully installed PyWavelets-1.8.0 imagehash-4.3.2

# %% [markdown]
# ##### STEP 4: Helper Functions

# %%
def zip_files(image_files_path, zip_filename, whitelist=None):
  count = 0
  with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, dirs, files in os.walk(image_files_path):
        for file in files:
          if whitelist and file not in whitelist:
            continue
          file_path = os.path.join(root, file)
          zipf.write(file_path, os.path.relpath(file_path, image_files_path))
          count += 1
  print(f"{count} files from folder {image_files_path} have been zipped as {zip_filename}")

# %%
def zip_to_colab(zip_file_path, extract_dir_name):
  extract_dir = '/content/' + extract_dir_name + "/"
  os.makedirs(extract_dir, exist_ok=True)

  with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
      zip_ref.extractall(extract_dir)

  print(f"Files from {zip_file_path} extracted to: {extract_dir}")
  print("Number of files extracted:", len(os.listdir(extract_dir)))

# %%
def get_file_extensions(folder_path):
    files = os.listdir(folder_path)

    extensions = set()

    for file in files:
        if os.path.isfile(os.path.join(folder_path, file)):
            extensions.add(os.path.splitext(file)[1])

    return extensions

# %%
# Source: https://github.com/cw-somil/Duplicate-Remover

from PIL import Image
import imagehash
import numpy as np

class DuplicateRemover:
    def __init__(self,dirname,hash_size = 8):
        self.dirname = dirname
        self.hash_size = hash_size

    def find_duplicates(self):
        """
        Find and Delete Duplicates
        """

        fnames = os.listdir(self.dirname)
        hashes = {}
        duplicates = []
        print("Finding Duplicates Now!\n")
        for image in fnames:
            with Image.open(os.path.join(self.dirname,image)) as img:
                temp_hash = imagehash.average_hash(img, self.hash_size)
                if temp_hash in hashes:
                    print("Duplicate {} \nfound for Image {}!\n".format(image,hashes[temp_hash]))
                    duplicates.append(image)
                else:
                    hashes[temp_hash] = image

        if len(duplicates) != 0:
            a = input("Do you want to delete these {} Images? Press Y or N:  ".format(len(duplicates)))
            space_saved = 0
            if(a.strip().lower() == "y"):
                for duplicate in duplicates:
                    space_saved += os.path.getsize(os.path.join(self.dirname,duplicate))

                    os.remove(os.path.join(self.dirname,duplicate))
                    print("{} Deleted Succesfully!".format(duplicate))

                print("\n\nYou saved {} mb of Space!".format(round(space_saved/1000000),2))
            else:
                print("Thank you for Using Duplicate Remover")
        else:
            print("No Duplicates Found :(")

    def find_similar(self,location,similarity=95):
        fnames = os.listdir(self.dirname)
        threshold = 1 - similarity/100
        diff_limit = int(threshold*(self.hash_size**2))

        with Image.open(location) as img:
            hash1 = imagehash.average_hash(img, self.hash_size).hash

        print("Finding Similar Images to {} Now!\n".format(location))
        for image in fnames:
            with Image.open(os.path.join(self.dirname,image)) as img:
                hash2 = imagehash.average_hash(img, self.hash_size).hash

                if np.count_nonzero(hash1 != hash2) <= diff_limit:
                    print("{} image found {}% similar to {}".format(image,similarity,location))

# %% [markdown]
# ## PART 2: "Human Faces" Dataset
#
# Dataset Source: ["Human Faces" by Ashwin Gupta](https://www.kaggle.com/datasets/ashwingupta3012/human-faces/data)
#
# Loads the dataset from Kaggle through the Kaggle API before removing duplicate images and zipping the files to the drive.

# %% [markdown]
# ##### STEP 1: Import the data from Kaggle using Kaggle API

# %% [markdown]
# 1. Load the raw dataset files from Kaggle

# %%
human_faces_path = kagglehub.dataset_download("ashwingupta3012/human-faces")

print("Path to dataset files:", human_faces_path)
# Out:
# Path to dataset files: /kaggle/input/human-faces

# %% [markdown]
# 2. Store raw dataset files to drive  (Necessary if Kaggle stored in /input/ folder.)

# %%
zip_files(human_faces_path, drive_path + '/HumanFacesDataset.zip')
# Out:
# Folder /kaggle/input/human-faces zipped as drive/MyDrive/HumanFacesDataset.zip

# %% [markdown]
# ##### STEP 2: Basic File Exploration

# %% [markdown]
# 1. Check what was downloaded from Kaggle

# %%
os.listdir(human_faces_path)
# Out:
# ['Humans']

# %% [markdown]
# 2. Check the Humans Folder

# %%
human_faces_image_folder = human_faces_path + '/Humans/'
human_faces_image_folder_filenames = os.listdir(human_faces_image_folder)
HUMANFACES_IMG_EXTENSIONS = get_file_extensions(human_faces_image_folder)


print("Number of image files:", len(human_faces_image_folder_filenames))
print("First 10 Files:", human_faces_image_folder_filenames[:10]) # Check the first 10 files
print("Image file extensions:", HUMANFACES_IMG_EXTENSIONS)
# Out:
# Number of image files: 7219
# First 10 Files: ['1 (2916).jpg', '1 (607).jpg', '1 (3767).jpg', '1 (576).jpg', '1 (1856).jpg', '1 (1464).jpg', '1 (1290).jpg', '1 (1341).jpg', '1 (2598).jpg', '1 (789).jpg']
# Image file extensions: {'.jpeg', '.jpg', '.JPG', '.png'}

# %% [markdown]
# ##### STEP 3: Clean the Data
#
# References:
# 1. ["Deleting duplicated images" by saworz](https://www.kaggle.com/code/saworz/deleting-duplicated-images?scriptVersionId=108951245)

# %% [markdown]
# 1. Load the raw dataset files (Necessary if Kaggle stored in /input/ folder.)

# %%
zip_to_colab(drive_path + "/HumanFacesDataset.zip", "HumanFacesImages")
# Out:
# Files from drive/MyDrive/HumanFacesDataset.zip extracted to: /content/HumanFacesImages/
# Number of files extracted: 1

# %%
# Reset stored folder, filenames, and extensions

human_faces_image_folder = "/content/HumanFacesImages/Humans/"
human_faces_image_folder_filenames = os.listdir(human_faces_image_folder)
HUMANFACES_IMG_EXTENSIONS = get_file_extensions(human_faces_image_folder)

print("Number of image files:", len(human_faces_image_folder_filenames))
print("First 10 Files:", human_faces_image_folder_filenames[:10]) # Check the first 10 files
print("Image file extensions:", HUMANFACES_IMG_EXTENSIONS)
# Out:
# Number of image files: 7219
# First 10 Files: ['1 (3266).jpg', '1 (3452).jpg', '1 (5516).jpg', '1 (4032).jpg', '1 (3295).jpg', '1 (1016).jpg', '1 (2832).jpg', '1 (5160).jpg', '1 (1369).jpg', '1 (3636).jpg']
# Image file extensions: {'.jpeg', '.jpg', '.JPG', '.png'}

# %% [markdown]
# 2. Rename the files

# %%
for file_name in human_faces_image_folder_filenames:
    filetype = file_name[file_name.index("."):]
    file_number = file_name[file_name.index("(") + 1: file_name.index(")")]
    new_name = "HF_" + file_number + filetype
    os.rename(os.path.join(human_faces_image_folder, file_name),
              os.path.join(human_faces_image_folder, new_name))
    print(file_name, "was renamed to", new_name)
# Out:
# 1 (3266).jpg was renamed to HF_3266.jpg
# 1 (3452).jpg was renamed to HF_3452.jpg
# 1 (5516).jpg was renamed to HF_5516.jpg
# 1 (4032).jpg was renamed to HF_4032.jpg
# 1 (3295).jpg was renamed to HF_3295.jpg
# 1 (1016).jpg was renamed to HF_1016.jpg
# 1 (2832).jpg was renamed to HF_2832.jpg
# 1 (5160).jpg was renamed to HF_5160.jpg
# 1 (1369).jpg was renamed to HF_1369.jpg
# 1 (3636).jpg was renamed to HF_3636.jpg
# 1 (2147).jpg was renamed to HF_2147.jpg
# 1 (3184).jpg was renamed to HF_3184.jpg
# 1 (3999).jpg was renamed to HF_3999.jpg
# 1 (1065).jpg was renamed to HF_1065.jpg
# 1 (4141).jpg was renamed to HF_4141.jpg
# 1 (4725).jpg was renamed to HF_4725.jpg
# 1 (94).jpg was renamed to HF_94.jpg
# 1 (3658).jpg was renamed to HF_3658.jpg
# 1 (1081).jpg was renamed to HF_1081.jpg
# 1 (5502).jpg was renamed to HF_5502.jpg
# 1 (1934).jpg was renamed to HF_1934.jpg
# 1 (1909).jpg was renamed to HF_1909.jpg
# 1 (1427).jpg was renamed to HF_1427.jpg
# 1 (4441).jpg was renamed to HF_4441.jpg
# 1 (844).jpg was renamed to HF_844.jpg
# 1 (49).png was renamed to HF_49.png
# 1 (6727).jpg was renamed to HF_6727.jpg
# 1 (3727).jpg was renamed to HF_3727.jpg
# 1 (584).jpg was renamed to HF_584.jpg
# 1 (2119).jpg was renamed to HF_2119.jpg
# 1 (3577).jpg was renamed to HF_3577.jpg
# 1 (1949).jpg was renamed to HF_1949.jpg
# 1 (407).jpg was renamed to HF_407.jpg
# 1 (3118).jpg was renamed to HF_3118.jpg
# 1 (573).jpg was renamed to HF_573.jpg
# 1 (414).jpg was renamed to HF_414.jpg
# 1 (1168).jpg was renamed to HF_1168.jpg
# 1 (4685).jpg was renamed to HF_4685.jpg
# 1 (4402).jpg was renamed to HF_4402.jpg
# 1 (3840).jpg was renamed to HF_3840.jpg
# 1 (6484).jpg was renamed to HF_6484.jpg
# 1 (4234).jpg was renamed to HF_4234.jpg
# 1 (3775).jpg was renamed to HF_3775.jpg
# 1 (5048).jpg was renamed to HF_5048.jpg
# 1 (1260).jpg was renamed to HF_1260.jpg
# 1 (777).jpg was renamed to HF_777.jpg
# 1 (5224).jpg was renamed to HF_5224.jpg
# 1 (663).jpg was renamed to HF_663.jpg
# 1 (4421).jpg was renamed to HF_4421.jpg
# 1 (6721).jpg was renamed to HF_6721.jpg
# 1 (5072).jpg was renamed to HF_5072.jpg
# 1 (603).jpg was renamed to HF_603.jpg
# 1 (6059).jpg was renamed to HF_6059.jpg
# 1 (5737).jpg was renamed to HF_5737.jpg
# 1 (5695).jpg was renamed to HF_5695.jpg
# 1 (6987).jpg was renamed to HF_6987.jpg
# 1 (2139).jpg was renamed to HF_2139.jpg
# 1 (5281).jpg was renamed to HF_5281.jpg

# %% [markdown]
# 3. Remove all duplicate images

# %%
dr = DuplicateRemover(human_faces_image_folder)
dr.find_duplicates()
# Out:
# Finding Duplicates Now!
#
# Duplicate HF_764.jpg
# found for Image HF_918.jpg!
#
# Duplicate HF_4427.jpg
# found for Image HF_5045.jpg!
#
# Duplicate HF_1488.jpg
# found for Image HF_2066.jpg!
#
# Duplicate HF_2259.jpg
# found for Image HF_1394.jpg!
#
# Duplicate HF_3432.jpg
# found for Image HF_3049.jpg!
#
# Duplicate HF_2785.jpg
# found for Image HF_3836.jpg!
#
# Duplicate HF_2107.jpg
# found for Image HF_1454.jpg!
#
# Duplicate HF_1401.jpg
# found for Image HF_286.jpg!
#
# Duplicate HF_1164.jpg
# found for Image HF_1983.jpg!
#
# Duplicate HF_4898.jpg
# found for Image HF_5123.jpg!
#
# Duplicate HF_4109.jpg
# found for Image HF_4331.jpg!
#
# Duplicate HF_4010.jpg
# found for Image HF_3786.jpg!
#
# Duplicate HF_2542.jpg
# found for Image HF_2014.jpg!
#
# Duplicate HF_4620.jpg
# found for Image HF_5097.jpg!
#
# Duplicate HF_3095.jpg
# found for Image HF_5046.jpg!
#
# Duplicate HF_2881.jpg
# found for Image HF_4358.jpg!
#
# Duplicate HF_915.jpg
# found for Image HF_2066.jpg!
#
# Duplicate HF_2484.jpg
# found for Image HF_1422.jpg!
#
# Duplicate HF_2632.jpg
# found for Image HF_334.jpg!
#
# Duplicate HF_2242.jpg
# found for Image HF_2502.jpg!
#
# Duplicate HF_675.jpg
# found for Image HF_2347.jpg!
#
# Duplicate HF_2260.jpg
# found for Image HF_918.jpg!
#
# Duplicate HF_5040.jpg
# found for Image HF_4133.jpg!
#
# Duplicate HF_261.jpg
# found for Image HF_1445.jpg!
#
# Duplicate HF_2639.jpg
# found for Image HF_1457.jpg!
#
# Duplicate HF_1019.jpg
# found for Image HF_2009.jpg!
#
# Duplicate HF_1101.jpg
# found for Image HF_1428.jpg!
#
# Duplicate HF_2451.jpg
# found for Image HF_1437.jpg!
#
# Duplicate HF_1334.jpg
# found for Image HF_1292.jpg!
#
# Duplicate HF_1373.jpg
# found for Image HF_524.jpg!
#
# Duplicate HF_3645.jpg
# found for Image HF_4704.jpg!
#
# Duplicate HF_4148.jpg
# found for Image HF_2972.jpg!
#
# Duplicate HF_2378.jpg
# found for Image HF_1901.jpg!
#
# Duplicate HF_2432.jpg
# found for Image HF_146.jpg!
#
# Duplicate HF_3794.jpg
# found for Image HF_5097.jpg!
#
# Duplicate HF_1239.jpg
# found for Image HF_2063.jpg!
#
# Duplicate HF_1186.jpg
# found for Image HF_393.jpg!
#
# Duplicate HF_3238.jpg
# found for Image HF_5121.jpg!
#
# Duplicate HF_632.jpg
# found for Image HF_2502.jpg!
#
# Duplicate HF_1504.jpg
# found for Image HF_843.jpg!
#
# Duplicate HF_2653.jpg
# found for Image HF_82.jpg!
#
# Duplicate HF_2126.jpg
# found for Image HF_918.jpg!
#
# Duplicate HF_3009.jpg
# found for Image HF_4743.jpg!
#
# Duplicate HF_2349.jpg
# found for Image HF_1884.jpg!
#
# Duplicate HF_4456.jpg
# found for Image HF_3170.jpg!
#
# Duplicate HF_10.jpeg
# found for Image HF_15.jpeg!
#
# Duplicate HF_2121.jpg
# found for Image HF_2063.jpg!
#
# Duplicate HF_4563.jpg
# found for Image HF_3602.jpg!
#
# Duplicate HF_633.jpg
# found for Image HF_734.jpg!
#
# Duplicate HF_2723.jpg
# found for Image HF_4088.jpg!
#
# Duplicate HF_2497.jpg
# found for Image HF_2096.jpg!
#
# Duplicate HF_1126.jpg
# found for Image HF_2293.jpg!
#
# Duplicate HF_3934.jpg
# found for Image HF_4781.jpg!
#
# Duplicate HF_2751.jpg
# found for Image HF_4688.jpg!
#
# Duplicate HF_4434.jpg
# found for Image HF_3844.jpg!
#
# Duplicate HF_4523.jpg
# found for Image HF_4856.jpg!
#
# Duplicate HF_2595.jpg
# found for Image HF_898.jpg!
#
# Duplicate HF_2.png
# found for Image HF_780.jpg!
#
# Duplicate HF_4849.jpg
# found for Image HF_3170.jpg!
#
# Duplicate HF_1805.jpg
# found for Image HF_2063.jpg!
#
# Duplicate HF_662.jpg
# found for Image HF_2096.jpg!
#
# Duplicate HF_4552.jpg
# found for Image HF_4441.jpg!
#
# Duplicate HF_4885.jpg
# found for Image HF_4430.jpg!
#
# Duplicate HF_4987.jpg
# found for Image HF_4170.jpg!
#
# Duplicate HF_3672.jpg
# found for Image HF_4165.jpg!
#
# Duplicate HF_3717.jpg
# found for Image HF_4677.jpg!
#
# Duplicate HF_2512.jpg
# found for Image HF_759.jpg!
#
# Duplicate HF_5032.jpg
# found for Image HF_4882.jpg!
#
# Duplicate HF_1730.jpg
# found for Image HF_328.jpg!
#
# Duplicate HF_1124.jpg
# found for Image HF_2063.jpg!
#
# Duplicate HF_191.jpg
# found for Image HF_1394.jpg!
#
# Duplicate HF_862.jpg
# found for Image HF_2514.jpg!
#
# Duplicate HF_2814.jpg
# found for Image HF_3170.jpg!
#
# Duplicate HF_4804.jpg
# found for Image HF_3534.jpg!
#
# Duplicate HF_1964.jpg
# found for Image HF_1216.jpg!
#
# Duplicate HF_2125.jpg
# found for Image HF_1501.jpg!
#
# Duplicate HF_2381.jpg
# found for Image HF_108.jpg!
#
# Duplicate HF_3964.jpg
# found for Image HF_5167.jpg!
#
# Duplicate HF_4512.jpg
# found for Image HF_4035.jpg!
#
# Duplicate HF_4089.jpg
# found for Image HF_2895.jpg!
#
# Duplicate HF_1797.jpg
# found for Image HF_2096.jpg!
#
# Duplicate HF_3747.jpg
# found for Image HF_4751.jpg!
#
# Duplicate HF_4927.jpg
# found for Image HF_2880.jpg!
#
# Duplicate HF_1196.jpg
# found for Image HF_1457.jpg!
#
# Duplicate HF_1734.jpg
# found for Image HF_697.jpg!
#
# Duplicate HF_1956.jpg
# found for Image HF_618.jpg!
#
# Duplicate HF_2067.jpg
# found for Image HF_2502.jpg!
#
# Duplicate HF_2543.jpg
# found for Image HF_497.jpg!
#
# Duplicate HF_869.jpg
# found for Image HF_1462.jpg!
#
# Duplicate HF_1743.jpg
# found for Image HF_2100.jpg!
#
# Duplicate HF_5118.jpg
# found for Image HF_3233.jpg!
#
# Duplicate HF_1744.jpg
# found for Image HF_292.jpg!
#
# Duplicate HF_551.jpg
# found for Image HF_2100.jpg!
#
# Duplicate HF_2764.jpg
# found for Image HF_4471.jpg!
#
# Duplicate HF_5084.jpg
# found for Image HF_4860.jpg!
#
# Duplicate HF_2324.jpg
# found for Image HF_249.jpg!
#
# Duplicate HF_1207.jpg
# found for Image HF_231.jpg!
#
# Duplicate HF_3164.jpg
# found for Image HF_4842.jpg!
#
# Duplicate HF_3386.jpg
# found for Image HF_4867.jpg!
#
# Duplicate HF_1603.jpg
# found for Image HF_2009.jpg!
#
# Duplicate HF_4536.jpg
# found for Image HF_4699.jpg!
#
# Duplicate HF_2749.jpg
# found for Image HF_4331.jpg!
#
# Duplicate HF_4861.jpg
# found for Image HF_3375.jpg!
#
# Duplicate HF_469.jpg
# found for Image HF_1884.jpg!
#
# Duplicate HF_3427.jpg
# found for Image HF_3045.jpg!
#
# Duplicate HF_4424.jpg
# found for Image HF_5123.jpg!
#
# Duplicate HF_2088.jpg
# found for Image HF_1383.jpg!
#
# Duplicate HF_1798.jpg
# found for Image HF_2640.jpg!
#
# Duplicate HF_1510.jpg
# found for Image HF_1445.jpg!
#
# Duplicate HF_1084.jpg
# found for Image HF_1270.jpg!
#
# Duplicate HF_4850.jpg
# found for Image HF_2895.jpg!
#
# Duplicate HF_3724.jpg
# found for Image HF_3375.jpg!
#
# Duplicate HF_112.jpg
# found for Image HF_1901.jpg!
#
# Duplicate HF_3505.jpg
# found for Image HF_5008.jpg!
#
# Duplicate HF_4479.jpg
# found for Image HF_3375.jpg!
#
# Duplicate HF_1672.jpg
# found for Image HF_2347.jpg!
#
# Duplicate HF_676.jpg
# found for Image HF_1285.jpg!
#
# Duplicate HF_2918.jpg
# found for Image HF_3598.jpg!
#
# Duplicate HF_1158.jpg
# found for Image HF_1823.jpg!
#
# Duplicate HF_607.jpg
# found for Image HF_1149.jpg!
#
# Duplicate HF_1293.jpg
# found for Image HF_2649.jpg!
#
# Duplicate HF_1023.jpg
# found for Image HF_2170.jpg!
#
# Duplicate HF_5107.jpg
# found for Image HF_4710.jpg!
#
# Duplicate HF_3088.jpg
# found for Image HF_3563.jpg!
#
# Duplicate HF_2619.jpg
# found for Image HF_1700.jpg!
#
# Duplicate HF_2608.jpg
# found for Image HF_1168.jpg!
#
# Duplicate HF_2614.jpg
# found for Image HF_1549.jpg!
#
# Duplicate HF_39.jpg
# found for Image HF_1235.jpg!
#
# Duplicate HF_4626.jpg
# found for Image HF_3207.jpg!
#
# Duplicate HF_1498.jpg
# found for Image HF_3975.jpg!
#
# Duplicate HF_4708.jpg
# found for Image HF_3519.jpg!
#
# Duplicate HF_108.png
# found for Image HF_150.png!
#
# Duplicate HF_3929.jpg
# found for Image HF_4444.jpg!
#
# Duplicate HF_2498.jpg
# found for Image HF_1168.jpg!
#
# Duplicate HF_355.jpg
# found for Image HF_146.jpg!
#
# Duplicate HF_4846.jpg
# found for Image HF_3641.jpg!
#
# Duplicate HF_4319.jpg
# found for Image HF_5128.jpg!
#
# Duplicate HF_2403.jpg
# found for Image HF_1549.jpg!
#
# Duplicate HF_2842.jpg
# found for Image HF_3530.jpg!
#
# Duplicate HF_4639.jpg
# found for Image HF_3589.jpg!
#
# Duplicate HF_1246.jpg
# found for Image HF_1070.jpg!
#
# Duplicate HF_1081.jpg
# found for Image HF_1447.jpg!
#
# Duplicate HF_4044.jpg
# found for Image HF_5102.jpg!
#
# Duplicate HF_674.jpg
# found for Image HF_1394.jpg!
#
# Duplicate HF_1136.jpg
# found for Image HF_1265.jpg!
#
# Duplicate HF_4188.jpg
# found for Image HF_4864.jpg!
#
# Duplicate HF_293.jpg
# found for Image HF_1983.jpg!
#
# Duplicate HF_7.jpg
# found for Image HF_734.jpg!
#
# Duplicate HF_4260.jpg
# found for Image HF_4146.jpg!
#
# Duplicate HF_2280.jpg
# found for Image HF_1178.jpg!
#
# Duplicate HF_1913.jpg
# found for Image HF_492.jpg!
#
# Duplicate HF_1090.jpg
# found for Image HF_2063.jpg!
#
# Duplicate HF_4350.jpg
# found for Image HF_4752.jpg!
#
# Duplicate HF_1638.jpg
# found for Image HF_45.jpg!
#
# Duplicate HF_5155.jpg
# found for Image HF_5005.jpg!
#
# Duplicate HF_4925.jpg
# found for Image HF_3823.jpg!
#
# Duplicate HF_4847.jpg
# found for Image HF_4190.jpg!
#
# Duplicate HF_499.jpg
# found for Image HF_1467.jpg!
#
# Duplicate HF_767.jpg
# found for Image HF_1780.jpg!
#
# Duplicate HF_324.jpg
# found for Image HF_531.jpg!
#
# Duplicate HF_5158.jpg
# found for Image HF_4712.jpg!
#
# Duplicate HF_4825.jpg
# found for Image HF_4154.jpg!
#
# Duplicate HF_2520.jpg
# found for Image HF_1780.jpg!
#
# Duplicate HF_4833.jpg
# found for Image HF_4170.jpg!
#
# Duplicate HF_2658.jpg
# found for Image HF_918.jpg!
#
# Duplicate HF_5054.jpg
# found for Image HF_2728.jpg!
#
# Duplicate HF_339.jpg
# found for Image HF_317.jpg!
#
# Duplicate HF_1930.jpg
# found for Image HF_531.jpg!
#
# Duplicate HF_2572.jpg
# found for Image HF_146.jpg!
#
# Duplicate HF_1057.jpg
# found for Image HF_2065.jpg!
#
# Duplicate HF_3259.jpg
# found for Image HF_3767.jpg!
#
# Duplicate HF_726.jpg
# found for Image HF_1642.jpg!
#
# Duplicate HF_1275.jpg
# found for Image HF_2370.jpg!
#
# Duplicate HF_3930.jpg
# found for Image HF_5176.jpg!
#
# Duplicate HF_3842.jpg
# found for Image HF_3295.jpg!
#
# Duplicate HF_1067.jpg
# found for Image HF_365.jpg!
#
# Duplicate HF_4166.jpg
# found for Image HF_4055.jpg!
#
# Duplicate HF_2151.jpg
# found for Image HF_2063.jpg!
#
# Duplicate HF_3732.jpg
# found for Image HF_4227.jpg!
#
# Duplicate HF_1611.jpg
# found for Image HF_146.jpg!
#
# Duplicate HF_77.jpeg
# found for Image HF_72.jpeg!
#
# Duplicate HF_1643.jpg
# found for Image HF_1133.jpg!
#
# Duplicate HF_2433.jpg
# found for Image HF_1220.jpg!
#
# Duplicate HF_2511.jpg
# found for Image HF_296.jpg!
#
# Duplicate HF_3551.jpg
# found for Image HF_4527.jpg!
#
# Duplicate HF_3169.jpg
# found for Image HF_3500.jpg!
#
# Duplicate HF_1521.jpg
# found for Image HF_1516.jpg!
#
# Duplicate HF_3141.jpg
# found for Image HF_3563.jpg!
#
# Duplicate HF_3277.jpg
# found for Image HF_4985.jpg!
#
# Duplicate HF_3733.jpg
# found for Image HF_4985.jpg!
#
# Duplicate HF_998.jpg
# found for Image HF_1221.jpg!
#
# Duplicate HF_1272.jpg
# found for Image HF_334.jpg!
#
# Duplicate HF_370.jpg
# found for Image HF_492.jpg!
#
# Duplicate HF_1240.jpg
# found for Image HF_2513.jpg!
#
# Duplicate HF_1712.jpg
# found for Image HF_2603.jpg!
#
# Duplicate HF_1971.jpg
# found for Image HF_2439.jpg!
#
# Duplicate HF_4022.jpg
# found for Image HF_3023.jpg!
#
# Duplicate HF_2265.jpg
# found for Image HF_82.jpg!
#
# Duplicate HF_368.jpg
# found for Image HF_492.jpg!
#
# Duplicate HF_3622.jpg
# found for Image HF_4366.jpg!
#
# Duplicate HF_2823.jpg
# found for Image HF_3682.jpg!
#
# Duplicate HF_672.jpg
# found for Image HF_317.jpg!
#
# Duplicate HF_3452.jpg
# found for Image HF_3221.jpg!
#
# Duplicate HF_1843.jpg
# found for Image HF_1166.jpg!
#
# Duplicate HF_4042.jpg
# found for Image HF_2809.jpg!
#
# Duplicate HF_3577.jpg
# found for Image HF_2903.jpg!
#
# Duplicate HF_3545.jpg
# found for Image HF_4181.jpg!
#
# Duplicate HF_567.jpg
# found for Image HF_1568.jpg!
#
# Duplicate HF_4034.jpg
# found for Image HF_4860.jpg!
#
# Duplicate HF_2161.jpg
# found for Image HF_1858.jpg!
#
# Duplicate HF_2054.jpg
# found for Image HF_1221.jpg!
#
# Duplicate HF_1049.jpg
# found for Image HF_1232.jpg!
#
# Duplicate HF_4786.jpg
# found for Image HF_4329.jpg!
#
# Duplicate HF_4636.jpg
# found for Image HF_4864.jpg!
#
# Duplicate HF_603.jpg
# found for Image HF_1454.jpg!
#
# Duplicate HF_18.png
# found for Image HF_780.jpg!
#
# Duplicate HF_2372.jpg
# found for Image HF_1147.jpg!
#
# Duplicate HF_2316.jpg
# found for Image HF_1850.jpg!
#
# Duplicate HF_5063.jpg
# found for Image HF_3571.jpg!
#
# Duplicate HF_1594.jpg
# found for Image HF_631.jpg!
#
# Duplicate HF_2854.jpg
# found for Image HF_555.jpg!
#
# Duplicate HF_2387.jpg
# found for Image HF_585.jpg!
#
# Duplicate HF_4264.jpg
# found for Image HF_2928.jpg!
#
# Duplicate HF_2626.jpg
# found for Image HF_898.jpg!
#
# Duplicate HF_4376.jpg
# found for Image HF_5121.jpg!
#
# Duplicate HF_47.jpeg
# found for Image HF_78.jpeg!
#
# Duplicate HF_3.jpg
# found for Image HF_2550.jpg!
#
# Duplicate HF_2739.jpg
# found for Image HF_4445.jpg!
#
# Duplicate HF_669.jpg
# found for Image HF_949.jpg!
#
# Duplicate HF_4066.jpg
# found for Image HF_4991.jpg!
#
# Duplicate HF_2578.jpg
# found for Image HF_1429.jpg!
#
# Duplicate HF_458.jpg
# found for Image HF_1150.jpg!
#
# Duplicate HF_4294.jpg
# found for Image HF_3221.jpg!
#
# Duplicate HF_1177.jpg
# found for Image HF_1806.jpg!
#
# Duplicate HF_1312.jpg
# found for Image HF_55.jpg!
#
# Duplicate HF_390.jpg
# found for Image HF_2063.jpg!
#
# Duplicate HF_5086.jpg
# found for Image HF_4366.jpg!
#
# Duplicate HF_1257.jpg
# found for Image HF_2331.jpg!
#
# Duplicate HF_1578.jpg
# found for Image HF_470.jpg!
#
# Duplicate HF_5026.jpg
# found for Image HF_3462.jpg!
#
# Duplicate HF_1079.jpg
# found for Image HF_634.jpg!
#
# Duplicate HF_160.jpg
# found for Image HF_146.jpg!
#
# Duplicate HF_4473.jpg
# found for Image HF_4049.jpg!
#
# Duplicate HF_4461.jpg
# found for Image HF_5060.jpg!
#
# Duplicate HF_4740.jpg
# found for Image HF_3590.jpg!
#
# Duplicate HF_3881.jpg
# found for Image HF_4864.jpg!
#
# Duplicate HF_855.jpg
# found for Image HF_1355.jpg!
#
# Duplicate HF_4591.jpg
# found for Image HF_3742.jpg!
#
# Duplicate HF_989.jpg
# found for Image HF_2423.jpg!
#
# Duplicate HF_4594.jpg
# found for Image HF_4751.jpg!
#
# Duplicate HF_4301.jpg
# found for Image HF_5172.jpg!
#
# Duplicate HF_163.jpg
# found for Image HF_1508.jpg!
#
# Duplicate HF_2969.jpg
# found for Image HF_5167.jpg!
#
# Duplicate HF_4595.jpg
# found for Image HF_5121.jpg!
#
# Duplicate HF_1230.jpg
# found for Image HF_2586.jpg!
#
# Duplicate HF_4101.jpg
# found for Image HF_4710.jpg!
#
# Duplicate HF_1813.jpg
# found for Image HF_264.jpg!
#
# Duplicate HF_5129.jpg
# found for Image HF_2878.jpg!
#
# Duplicate HF_1742.jpg
# found for Image HF_585.jpg!
#
# Duplicate HF_635.jpg
# found for Image HF_1027.jpg!
#
# Duplicate HF_1741.jpg
# found for Image HF_1404.jpg!
#
# Duplicate HF_1645.jpg
# found for Image HF_627.jpg!
#
# Duplicate HF_2355.jpg
# found for Image HF_2288.jpg!
#
# Duplicate HF_2069.jpg
# found for Image HF_103.jpg!
#
# Duplicate HF_4280.jpg
# found for Image HF_3114.jpg!
#
# Duplicate HF_1687.jpg
# found for Image HF_550.jpg!
#
# Duplicate HF_1247.jpg
# found for Image HF_461.jpg!
#
# Duplicate HF_430.jpg
# found for Image HF_1549.jpg!
#
# Duplicate HF_4304.jpg
# found for Image HF_3684.jpg!
#
# Duplicate HF_4052.jpg
# found for Image HF_4864.jpg!
#
# Duplicate HF_91.jpg
# found for Image HF_2187.jpg!
#
# Duplicate HF_2592.jpg
# found for Image HF_1890.jpg!
#
# Duplicate HF_2935.jpg
# found for Image HF_3403.jpg!
#
# Duplicate HF_3247.jpg
# found for Image HF_3403.jpg!
#
# Duplicate HF_4879.jpg
# found for Image HF_4064.jpg!
#
# Duplicate HF_4321.jpg
# found for Image HF_3583.jpg!
#
# Duplicate HF_1598.jpg
# found for Image HF_146.jpg!
#
# Duplicate HF_4604.jpg
# found for Image HF_2923.jpg!
#
# Duplicate HF_629.jpg
# found for Image HF_1437.jpg!
#
# Duplicate HF_4372.jpg
# found for Image HF_3233.jpg!
#
# Duplicate HF_3175.jpg
# found for Image HF_3991.jpg!
#
# Duplicate HF_3273.jpg
# found for Image HF_4583.jpg!
#
# Duplicate HF_4351.jpg
# found for Image HF_3632.jpg!
#
# Duplicate HF_4550.jpg
# found for Image HF_2895.jpg!
#
# Duplicate HF_89.jpg
# found for Image HF_2170.jpg!
#
# Duplicate HF_4894.jpg
# found for Image HF_5060.jpg!
#
# Duplicate HF_4518.jpg
# found for Image HF_3433.jpg!
#
# Duplicate HF_1228.jpg
# found for Image HF_991.jpg!
#
# Duplicate HF_4757.jpg
# found for Image HF_3941.jpg!
#
# Duplicate HF_4982.jpg
# found for Image HF_4710.jpg!
#
# Duplicate HF_121.png
# found for Image HF_97.png!
#
# Duplicate HF_4135.jpg
# found for Image HF_4686.jpg!
#
# Duplicate HF_3546.jpg
# found for Image HF_4684.jpg!
#
# Duplicate HF_4923.jpg
# found for Image HF_5060.jpg!
#
# Duplicate HF_3518.jpg
# found for Image HF_4175.jpg!
#
# Duplicate HF_4994.jpg
# found for Image HF_4069.jpg!
#
# Duplicate HF_1773.jpg
# found for Image HF_531.jpg!
#
# Duplicate HF_3290.jpg
# found for Image HF_4215.jpg!
#
# Duplicate HF_737.jpg
# found for Image HF_1404.jpg!
#
# Duplicate HF_52.jpg
# found for Image HF_1867.jpg!
#
# Duplicate HF_4984.jpg
# found for Image HF_4055.jpg!
#
# Duplicate HF_102.jpg
# found for Image HF_1302.jpg!
#
# Duplicate HF_4368.jpg
# found for Image HF_4035.jpg!
#
# Duplicate HF_800.jpg
# found for Image HF_3694.jpg!
#
# Duplicate HF_3899.jpg
# found for Image HF_4430.jpg!
#
# Duplicate HF_4784.jpg
# found for Image HF_3477.jpg!
#
# Duplicate HF_18.jpg
# found for Image HF_991.jpg!
#
# Duplicate HF_40.png
# found for Image HF_780.jpg!
#
# Duplicate HF_3905.jpg
# found for Image HF_4688.jpg!
#
# Duplicate HF_3212.jpg
# found for Image HF_4710.jpg!
#
# Duplicate HF_3426.jpg
# found for Image HF_3161.jpg!
#
# Duplicate HF_1160.jpg
# found for Image HF_1149.jpg!
#
# Duplicate HF_5022.jpg
# found for Image HF_3602.jpg!
#
# Duplicate HF_1790.jpg
# found for Image HF_878.jpg!
#
# Duplicate HF_266.jpg
# found for Image HF_1066.jpg!
#
# Duplicate HF_4511.jpg
# found for Image HF_3635.jpg!
#
# Duplicate HF_3183.jpg
# found for Image HF_3656.jpg!
#
# Duplicate HF_5028.jpg
# found for Image HF_3451.jpg!
#
# Duplicate HF_1310.jpg
# found for Image HF_2400.jpg!
#
# Duplicate HF_4525.jpg
# found for Image HF_4684.jpg!
#
# Duplicate HF_3281.jpg
# found for Image HF_4190.jpg!
#
# Duplicate HF_283.jpg
# found for Image HF_1497.jpg!
#
# Duplicate HF_508.jpg
# found for Image HF_2012.jpg!
#
# Duplicate HF_1547.jpg
# found for Image HF_546.jpg!
#
# Duplicate HF_4439.jpg
# found for Image HF_4985.jpg!
#
# Duplicate HF_4272.jpg
# found for Image HF_5008.jpg!
#
# Duplicate HF_3576.jpg
# found for Image HF_5045.jpg!
#
# Duplicate HF_2058.jpg
# found for Image HF_699.jpg!
#
# Duplicate HF_1652.jpg
# found for Image HF_634.jpg!
#
# Duplicate HF_4115.jpg
# found for Image HF_4710.jpg!
#
# Duplicate HF_4701.jpg
# found for Image HF_3462.jpg!
#
# Duplicate HF_1000.jpg
# found for Image HF_2581.jpg!
#
# Duplicate HF_5182.jpg
# found for Image HF_4781.jpg!
#
# Duplicate HF_3251.jpg
# found for Image HF_4055.jpg!
#
# Duplicate HF_3760.jpg
# found for Image HF_3393.jpg!
#
# Duplicate HF_1286.jpg
# found for Image HF_2618.jpg!
#
# Duplicate HF_3298.jpg
# found for Image HF_3851.jpg!
#
# Duplicate HF_3006.jpg
# found for Image HF_4334.jpg!
#
# Duplicate HF_1986.jpg
# found for Image HF_393.jpg!
#
# Duplicate HF_1032.jpg
# found for Image HF_2288.jpg!
#
# Duplicate HF_439.jpg
# found for Image HF_1983.jpg!
#
# Duplicate HF_1526.jpg
# found for Image HF_286.jpg!
#
# Duplicate HF_3970.jpg
# found for Image HF_4471.jpg!
#
# Duplicate HF_3123.jpg
# found for Image HF_3664.jpg!
#
# Duplicate HF_1072.jpg
# found for Image HF_353.jpg!
#
# Duplicate HF_683.jpg
# found for Image HF_1292.jpg!
#
# Duplicate HF_4248.jpg
# found for Image HF_4726.jpg!
#
# Duplicate HF_1159.jpg
# found for Image HF_1064.jpg!
#
# Duplicate HF_4077.jpg
# found for Image HF_4190.jpg!
#
# Duplicate HF_2345.jpg
# found for Image HF_1122.jpg!
#
# Duplicate HF_4058.jpg
# found for Image HF_4170.jpg!
#
# Duplicate HF_4615.jpg
# found for Image HF_3430.jpg!
#
# Duplicate HF_695.jpg
# found for Image HF_1292.jpg!
#
# Duplicate HF_1382.jpg
# found for Image HF_736.jpg!
#
# Duplicate HF_4071.jpg
# found for Image HF_4882.jpg!
#
# Duplicate HF_3029.jpg
# found for Image HF_3995.jpg!
#
# Duplicate HF_1893.jpg
# found for Image HF_1137.jpg!
#
# Duplicate HF_2557.jpg
# found for Image HF_75.jpg!
#
# Duplicate HF_2071.jpg
# found for Image HF_2293.jpg!
#
# Duplicate HF_4567.jpg
# found for Image HF_4651.jpg!
#
# Duplicate HF_3911.jpg
# found for Image HF_2923.jpg!
#
# Duplicate HF_1889.jpg
# found for Image HF_138.jpg!
#
# Duplicate HF_1165.jpg
# found for Image HF_2170.jpg!
#
# Duplicate HF_3138.jpg
# found for Image HF_3804.jpg!
#
# Duplicate HF_554.jpg
# found for Image HF_2159.jpg!
#
# Duplicate HF_66.jpg
# found for Image HF_1454.jpg!
#
# Duplicate HF_4883.jpg
# found for Image HF_5103.jpg!
#
# Duplicate HF_4075.jpg
# found for Image HF_4470.jpg!
#
# Duplicate HF_3874.jpg
# found for Image HF_4242.jpg!
#
# Duplicate HF_888.jpg
# found for Image HF_2201.jpg!
#
# Duplicate HF_107.png
# found for Image HF_84.png!
#
# Duplicate HF_1202.jpg
# found for Image HF_2000.jpg!
#
# Duplicate HF_2848.jpg
# found for Image HF_4981.jpg!
#
# Duplicate HF_821.jpg
# found for Image HF_1455.jpg!
#
# Duplicate HF_2094.jpg
# found for Image HF_921.jpg!
#
# Duplicate HF_1899.jpg
# found for Image HF_2293.jpg!
#
# Duplicate HF_3381.jpg
# found for Image HF_4864.jpg!
#
# Duplicate HF_3457.jpg
# found for Image HF_4395.jpg!
#
# Duplicate HF_5004.jpg
# found for Image HF_4358.jpg!
#
# Duplicate HF_3271.jpg
# found for Image HF_4069.jpg!
#
# Duplicate HF_4464.jpg
# found for Image HF_4037.jpg!
#
# Duplicate HF_1182.jpg
# found for Image HF_918.jpg!
#
# Duplicate HF_5185.jpg
# found for Image HF_4102.jpg!
#
# Duplicate HF_1820.jpg
# found for Image HF_853.jpg!
#
# Duplicate HF_4489.jpg
# found for Image HF_2841.jpg!
#
# Duplicate HF_1617.jpg
# found for Image HF_734.jpg!
#
# Duplicate HF_1512.jpg
# found for Image HF_2363.jpg!
#
# Duplicate HF_38.jpeg
# found for Image HF_72.jpeg!
#
# Duplicate HF_375.jpg
# found for Image HF_2575.jpg!
#
# Duplicate HF_4829.jpg
# found for Image HF_4981.jpg!
#
# Duplicate HF_2757.jpg
# found for Image HF_3623.jpg!
#
# Duplicate HF_2390.jpg
# found for Image HF_1726.jpg!
#
# Duplicate HF_905.jpg
# found for Image HF_2656.jpg!
#
# Duplicate HF_4027.jpg
# found for Image HF_4606.jpg!
#
# Duplicate HF_125.png
# found for Image HF_3684.jpg!
#
# Duplicate HF_4423.jpg
# found for Image HF_3721.jpg!
#
# Duplicate HF_4458.jpg
# found for Image HF_5166.jpg!
#
# Duplicate HF_1960.jpg
# found for Image HF_577.jpg!
#
# Duplicate HF_248.jpg
# found for Image HF_1516.jpg!
#
# Duplicate HF_932.jpg
# found for Image HF_108.jpg!
#
# Duplicate HF_4657.jpg
# found for Image HF_4093.jpg!
#
# Duplicate HF_4772.jpg
# found for Image HF_4146.jpg!
#
# Duplicate HF_889.jpg
# found for Image HF_1319.jpg!
#
# Duplicate HF_1474.jpg
# found for Image HF_353.jpg!
#
# Duplicate HF_3604.jpg
# found for Image HF_4743.jpg!
#
# Duplicate HF_2868.jpg
# found for Image HF_5123.jpg!
#
# Duplicate HF_1460.jpg
# found for Image HF_538.jpg!
#
# Duplicate HF_4078.jpg
# found for Image HF_3403.jpg!
#
# Duplicate HF_2113.jpg
# found for Image HF_1814.jpg!
#
# Duplicate HF_125.jpg
# found for Image HF_1845.jpg!
#
# Duplicate HF_4360.jpg
# found for Image HF_3045.jpg!
#
# Duplicate HF_281.jpg
# found for Image HF_2066.jpg!
#
# Duplicate HF_3595.jpg
# found for Image HF_2878.jpg!
#
# Duplicate HF_4795.jpg
# found for Image HF_4067.jpg!
#
# Duplicate HF_848.jpg
# found for Image HF_1070.jpg!
#
# Duplicate HF_70.png
# found for Image HF_150.png!
#
# Duplicate HF_143.jpg
# found for Image HF_1936.jpg!
#
# Duplicate HF_883.jpg
# found for Image HF_1476.jpg!
#
# Duplicate HF_1605.jpg
# found for Image HF_1123.jpg!
#
# Duplicate HF_52.jpeg
# found for Image HF_78.jpeg!
#
# Duplicate HF_1142.jpg
# found for Image HF_2130.jpg!
#
# Duplicate HF_4529.jpg
# found for Image HF_4004.jpg!
#
# Duplicate HF_1970.jpg
# found for Image HF_863.jpg!
#
# Duplicate HF_3797.jpg
# found for Image HF_3092.jpg!
#
# Duplicate HF_3784.jpg
# found for Image HF_4691.jpg!
#
# Duplicate HF_3209.jpg
# found for Image HF_3878.jpg!
#
# Duplicate HF_87.png
# found for Image HF_72.png!
#
# Duplicate HF_436.jpg
# found for Image HF_1215.jpg!
#
# Duplicate HF_3125.jpg
# found for Image HF_3581.jpg!
#
# Duplicate HF_2931.jpg
# found for Image HF_3998.jpg!
#
# Duplicate HF_1671.jpg
# found for Image HF_1487.jpg!
#
# Duplicate HF_2038.jpg
# found for Image HF_1394.jpg!
#
# Duplicate HF_3535.jpg
# found for Image HF_3944.jpg!
#
# Duplicate HF_93.jpg
# found for Image HF_1350.jpg!
#
# Duplicate HF_1144.jpg
# found for Image HF_605.jpg!
#
# Duplicate HF_4475.jpg
# found for Image HF_3439.jpg!
#
# Duplicate HF_2237.jpg
# found for Image HF_1639.jpg!
#
# Duplicate HF_1759.jpg
# found for Image HF_738.jpg!
#
# Duplicate HF_4609.jpg
# found for Image HF_5122.jpg!
#
# Duplicate HF_2357.jpg
# found for Image HF_918.jpg!
#
# Duplicate HF_1390.jpg
# found for Image HF_2066.jpg!
#
# Duplicate HF_1562.jpg
# found for Image HF_768.jpg!
#
# Duplicate HF_2135.jpg
# found for Image HF_1133.jpg!
#
# Duplicate HF_4123.jpg
# found for Image HF_4035.jpg!
#
# Duplicate HF_2850.jpg
# found for Image HF_5177.jpg!
#
# Duplicate HF_565.jpg
# found for Image HF_1137.jpg!
#
# Duplicate HF_1324.jpg
# found for Image HF_1065.jpg!
#
# Duplicate HF_1338.jpg
# found for Image HF_1383.jpg!
#
# Duplicate HF_4877.jpg
# found for Image HF_3880.jpg!
#
# Duplicate HF_2720.jpg
# found for Image HF_4710.jpg!
#
# Duplicate HF_3181.jpg
# found for Image HF_4329.jpg!
#
# Duplicate HF_2146.jpg
# found for Image HF_1206.jpg!
#
# Duplicate HF_2839.jpg
# found for Image HF_4154.jpg!
#
# Duplicate HF_2574.jpg
# found for Image HF_1959.jpg!
#
# Duplicate HF_1470.jpg
# found for Image HF_1027.jpg!
#
# Duplicate HF_3948.jpg
# found for Image HF_3222.jpg!
#
# Duplicate HF_352.jpg
# found for Image HF_2211.jpg!
#
# Duplicate HF_4561.jpg
# found for Image HF_2145.jpg!
#
# Duplicate HF_3757.jpg
# found for Image HF_2872.jpg!
#
# Duplicate HF_3693.jpg
# found for Image HF_4700.jpg!
#
# Duplicate HF_4178.jpg
# found for Image HF_4991.jpg!
#
# Duplicate HF_4589.jpg
# found for Image HF_5115.jpg!
#
# Duplicate HF_2325.jpg
# found for Image HF_631.jpg!
#
# Duplicate HF_2636.jpg
# found for Image HF_146.jpg!
#
# Duplicate HF_4141.jpg
# found for Image HF_3500.jpg!
#
# Duplicate HF_1701.jpg
# found for Image HF_916.jpg!
#
# Duplicate HF_4687.jpg
# found for Image HF_4527.jpg!
#
# Duplicate HF_8.png
# found for Image HF_53.png!
#
# Duplicate HF_1242.jpg
# found for Image HF_1975.jpg!
#
# Duplicate HF_2222.jpg
# found for Image HF_1683.jpg!
#
# Duplicate HF_2224.jpg
# found for Image HF_1963.jpg!
#
# Duplicate HF_483.jpg
# found for Image HF_1539.jpg!
#
# Duplicate HF_935.jpg
# found for Image HF_299.jpg!
#
# Duplicate HF_929.jpg
# found for Image HF_492.jpg!
#
# Duplicate HF_4164.jpg
# found for Image HF_3939.jpg!
#
# Duplicate HF_4196.jpg
# found for Image HF_4961.jpg!
#
# Duplicate HF_3679.jpg
# found for Image HF_4300.jpg!
#
# Duplicate HF_783.jpg
# found for Image HF_863.jpg!
#
# Duplicate HF_729.jpg
# found for Image HF_531.jpg!
#
# Duplicate HF_626.jpg
# found for Image HF_1501.jpg!
#
# Duplicate HF_4549.jpg
# found for Image HF_3372.jpg!
#
# Duplicate HF_29.jpeg
# found for Image HF_71.jpeg!
#
# Duplicate HF_348.jpg
# found for Image HF_2571.jpg!
#
# Duplicate HF_3582.jpg
# found for Image HF_3421.jpg!
#
# Duplicate HF_4118.jpg
# found for Image HF_4800.jpg!
#
# Duplicate HF_4834.jpg
# found for Image HF_5102.jpg!
#
# Duplicate HF_1328.jpg
# found for Image HF_918.jpg!
#
# Duplicate HF_4416.jpg
# found for Image HF_4872.jpg!
#
# Duplicate HF_3507.jpg
# found for Image HF_2945.jpg!
#
# Duplicate HF_4045.jpg
# found for Image HF_4282.jpg!
#
# Duplicate HF_1592.jpg
# found for Image HF_1133.jpg!
#
# Duplicate HF_1602.jpg
# found for Image HF_1134.jpg!
#
# Duplicate HF_3442.jpg
# found for Image HF_4329.jpg!
#
# Duplicate HF_2684.jpg
# found for Image HF_5172.jpg!
#
# Duplicate HF_2786.jpg
# found for Image HF_3602.jpg!
#
# Duplicate HF_777.jpg
# found for Image HF_1383.jpg!
#
# Duplicate HF_3070.jpg
# found for Image HF_3430.jpg!
#
# Duplicate HF_4680.jpg
# found for Image HF_3632.jpg!
#
# Duplicate HF_1666.jpg
# found for Image HF_2304.jpg!
#
# Duplicate HF_5068.jpg
# found for Image HF_4710.jpg!
#
# Duplicate HF_2085.jpg
# found for Image HF_918.jpg!
#
# Duplicate HF_3404.jpg
# found for Image HF_4216.jpg!
#
# Duplicate HF_3788.jpg
# found for Image HF_5121.jpg!
#
# Duplicate HF_4939.jpg
# found for Image HF_4216.jpg!
#
# Duplicate HF_4711.jpg
# found for Image HF_5167.jpg!
#
# Duplicate HF_257.jpg
# found for Image HF_1807.jpg!
#
# Duplicate HF_802.jpg
# found for Image HF_1155.jpg!
#
# Duplicate HF_1039.jpg
# found for Image HF_1814.jpg!
#
# Duplicate HF_1403.jpg
# found for Image HF_1007.jpg!
#
# Duplicate HF_1174.jpg
# found for Image HF_2550.jpg!
#
# Duplicate HF_3780.jpg
# found for Image HF_2928.jpg!
#
# Duplicate HF_4539.jpg
# found for Image HF_5102.jpg!
#
# Duplicate HF_1684.jpg
# found for Image HF_1065.jpg!
#
# Duplicate HF_4747.jpg
# found for Image HF_4441.jpg!
#
# Duplicate HF_2108.jpg
# found for Image HF_2601.jpg!
#
# Duplicate HF_4316.jpg
# found for Image HF_4726.jpg!
#
# Duplicate HF_43.jpg
# found for Image HF_1445.jpg!
#
# Duplicate HF_4859.jpg
# found for Image HF_5102.jpg!
#
# Duplicate HF_428.jpg
# found for Image HF_1421.jpg!
#
# Duplicate HF_5003.jpg
# found for Image HF_2895.jpg!
#
# Duplicate HF_1634.jpg
# found for Image HF_2458.jpg!
#
# Duplicate HF_2856.jpg
# found for Image HF_4913.jpg!
#
# Duplicate HF_2813.jpg
# found for Image HF_3677.jpg!
#
# Duplicate HF_4476.jpg
# found for Image HF_3335.jpg!
#
# Duplicate HF_3358.jpg
# found for Image HF_3498.jpg!
#
# Duplicate HF_1290.jpg
# found for Image HF_2130.jpg!
#
# Duplicate HF_4705.jpg
# found for Image HF_4282.jpg!
#
# Duplicate HF_2412.jpg
# found for Image HF_299.jpg!
#
# Duplicate HF_4009.jpg
# found for Image HF_2915.jpg!
#
# Duplicate HF_2469.jpg
# found for Image HF_2001.jpg!
#
# Duplicate HF_255.jpg
# found for Image HF_4470.jpg!
#
# Duplicate HF_289.jpg
# found for Image HF_966.jpg!
#
# Duplicate HF_4236.jpg
# found for Image HF_3154.jpg!
#
# Duplicate HF_1555.jpg
# found for Image HF_763.jpg!
#
# Duplicate HF_741.jpg
# found for Image HF_2009.jpg!
#
# Duplicate HF_3765.jpg
# found for Image HF_4358.jpg!
#
# Duplicate HF_4980.jpg
# found for Image HF_3288.jpg!
#
# Duplicate HF_1832.jpg
# found for Image HF_253.jpg!
#
# Duplicate HF_3447.jpg
# found for Image HF_4490.jpg!
#
# Duplicate HF_2459.jpg
# found for Image HF_1538.jpg!
#
# Duplicate HF_3330.jpg
# found for Image HF_2004.jpg!
#
# Duplicate HF_2925.jpg
# found for Image HF_3393.jpg!
#
# Duplicate HF_2173.jpg
# found for Image HF_871.jpg!
#
# Duplicate HF_2257.jpg
# found for Image HF_14.jpg!
#
# Duplicate HF_3872.jpg
# found for Image HF_4912.jpg!
#
# Duplicate HF_2909.jpg
# found for Image HF_5097.jpg!
#
# Duplicate HF_587.jpg
# found for Image HF_1133.jpg!
#
# Duplicate HF_4766.jpg
# found for Image HF_4455.jpg!
#
# Duplicate HF_725.jpg
# found for Image HF_1800.jpg!
#
# Duplicate HF_1678.jpg
# found for Image HF_1206.jpg!
#
# Duplicate HF_4801.jpg
# found for Image HF_2673.jpg!
#
# Duplicate HF_118.png
# found for Image HF_84.png!
#
# Duplicate HF_912.jpg
# found for Image HF_365.jpg!
#
# Duplicate HF_3752.jpg
# found for Image HF_4752.jpg!
#
# Duplicate HF_3888.jpg
# found for Image HF_3641.jpg!
#
# Duplicate HF_1491.jpg
# found for Image HF_1150.jpg!
#
# Duplicate HF_2206.jpg
# found for Image HF_492.jpg!
#
# Duplicate HF_1163.jpg
# found for Image HF_1383.jpg!
#
# Duplicate HF_4256.jpg
# found for Image HF_3047.jpg!
#
# Duplicate HF_4202.jpg
# found for Image HF_3295.jpg!
#
# Duplicate HF_4770.jpg
# found for Image HF_4466.jpg!
#
# Duplicate HF_30.png
# found for Image HF_53.png!
#
# Duplicate HF_4501.jpg
# found for Image HF_4017.jpg!
#
# Duplicate HF_13.jpeg
# found for Image HF_17.jpeg!
#
# Duplicate HF_1914.jpg
# found for Image HF_2656.jpg!
#
# Duplicate HF_193.jpg
# found for Image HF_103.jpg!
#
# Duplicate HF_2419.jpg
# found for Image HF_552.jpg!
#
# Duplicate HF_2449.jpg
# found for Image HF_1215.jpg!
#
# Duplicate HF_2024.jpg
# found for Image HF_77.jpg!
#
# Duplicate HF_202.jpg
# found for Image HF_561.jpg!
#
# Duplicate HF_616.jpg
# found for Image HF_2284.jpg!
#
# Duplicate HF_4730.jpg
# found for Image HF_5039.jpg!
#
# Duplicate HF_66.png
# found for Image HF_102.png!
#
# Duplicate HF_3389.jpg
# found for Image HF_4949.jpg!
#
# Duplicate HF_5052.jpg
# found for Image HF_3403.jpg!
#
# Duplicate HF_4392.jpg
# found for Image HF_2787.jpg!
#
# Duplicate HF_410.jpg
# found for Image HF_68.jpg!
#
# Duplicate HF_1740.jpg
# found for Image HF_898.jpg!
#
# Duplicate HF_495.jpg
# found for Image HF_1865.jpg!
#
# Duplicate HF_41.jpeg
# found for Image HF_71.jpeg!
#
# Duplicate HF_60.jpg
# found for Image HF_983.jpg!
#
# Duplicate HF_3344.jpg
# found for Image HF_3728.jpg!
#
# Duplicate HF_4081.jpg
# found for Image HF_2895.jpg!
#
# Duplicate HF_1309.jpg
# found for Image HF_108.jpg!
#
# Duplicate HF_4758.jpg
# found for Image HF_4175.jpg!
#
# Duplicate HF_1589.jpg
# found for Image HF_1620.jpg!
#
# Duplicate HF_1203.jpg
# found for Image HF_1455.jpg!
#
# Duplicate HF_1227.jpg
# found for Image HF_1803.jpg!
#
# Duplicate HF_3909.jpg
# found for Image HF_2701.jpg!
#
# Duplicate HF_2902.jpg
# found for Image HF_3433.jpg!
#
# Duplicate HF_2524.jpg
# found for Image HF_1708.jpg!
#
# Duplicate HF_212.jpg
# found for Image HF_1168.jpg!
#
# Duplicate HF_341.jpg
# found for Image HF_2570.jpg!
#
# Duplicate HF_3813.jpg
# found for Image HF_3260.jpg!
#
# Duplicate HF_3121.jpg
# found for Image HF_3786.jpg!
#
# Duplicate HF_3091.jpg
# found for Image HF_3684.jpg!
#
# Duplicate HF_2714.jpg
# found for Image HF_3739.jpg!
#
# Duplicate HF_1542.jpg
# found for Image HF_2603.jpg!
#
# Duplicate HF_3445.jpg
# found for Image HF_3850.jpg!
#
# Duplicate HF_50.png
# found for Image HF_780.jpg!
#
# Duplicate HF_1107.jpg
# found for Image HF_442.jpg!
#
# Duplicate HF_4111.jpg
# found for Image HF_5142.jpg!
#
# Duplicate HF_444.jpg
# found for Image HF_1845.jpg!
#
# Duplicate HF_1377.jpg
# found for Image HF_492.jpg!
#
# Duplicate HF_3284.jpg
# found for Image HF_3194.jpg!
#
# Duplicate HF_27.jpeg
# found for Image HF_48.jpeg!
#
# Duplicate HF_4969.jpg
# found for Image HF_4417.jpg!
#
# Duplicate HF_4020.jpg
# found for Image HF_4356.jpg!
#
# Duplicate HF_3792.jpg
# found for Image HF_3224.jpg!
#
# Duplicate HF_995.jpg
# found for Image HF_1551.jpg!
#
# Duplicate HF_1782.jpg
# found for Image HF_1220.jpg!
#
# Duplicate HF_4096.jpg
# found for Image HF_3589.jpg!
#
# Duplicate HF_434.jpg
# found for Image HF_2066.jpg!
#
# Duplicate HF_4824.jpg
# found for Image HF_4973.jpg!
#
# Duplicate HF_3898.jpg
# found for Image HF_3403.jpg!
#
# Duplicate HF_4548.jpg
# found for Image HF_2826.jpg!
#
# Duplicate HF_3336.jpg
# found for Image HF_4470.jpg!
#
# Duplicate HF_1973.jpg
# found for Image HF_2152.jpg!
#
# Duplicate HF_3355.jpg
# found for Image HF_3942.jpg!
#
# Duplicate HF_421.jpg
# found for Image HF_1166.jpg!
#
# Duplicate HF_1647.jpg
# found for Image HF_211.jpg!
#
# Duplicate HF_4634.jpg
# found for Image HF_2900.jpg!
#
# Duplicate HF_1253.jpg
# found for Image HF_280.jpg!
#
# Duplicate HF_3479.jpg
# found for Image HF_2670.jpg!
#
# Duplicate HF_4380.jpg
# found for Image HF_3192.jpg!
#
# Duplicate HF_1754.jpg
# found for Image HF_752.jpg!
#
# Duplicate HF_4696.jpg
# found for Image HF_5097.jpg!
#
# Duplicate HF_3764.jpg
# found for Image HF_4506.jpg!
#
# Duplicate HF_4057.jpg
# found for Image HF_3085.jpg!
#
# Duplicate HF_171.jpg
# found for Image HF_734.jpg!
#
# Duplicate HF_797.jpg
# found for Image HF_2066.jpg!
#
# Duplicate HF_1722.jpg
# found for Image HF_552.jpg!
#
# Duplicate HF_4297.jpg
# found for Image HF_3539.jpg!
#
# Duplicate HF_93.png
# found for Image HF_71.png!
#
# Duplicate HF_2961.jpg
# found for Image HF_5044.jpg!
#
# Duplicate HF_3566.jpg
# found for Image HF_5060.jpg!
#
# Duplicate HF_225.jpg
# found for Image HF_1814.jpg!
#
# Duplicate HF_1906.jpg
# found for Image HF_1221.jpg!
#
# Duplicate HF_2835.jpg
# found for Image HF_3721.jpg!
#
# Duplicate HF_1380.jpg
# found for Image HF_1887.jpg!
#
# Duplicate HF_3369.jpg
# found for Image HF_3665.jpg!
#
# Duplicate HF_263.jpg
# found for Image HF_1479.jpg!
#
# Duplicate HF_3938.jpg
# found for Image HF_3207.jpg!
#
# Duplicate HF_1128.jpg
# found for Image HF_1166.jpg!
#
# Duplicate HF_3345.jpg
# found for Image HF_4163.jpg!
#
# Duplicate HF_5136.jpg
# found for Image HF_3668.jpg!
#
# Duplicate HF_35.jpg
# found for Image HF_1007.jpg!
#
# Duplicate HF_980.jpg
# found for Image HF_734.jpg!
#
# Duplicate HF_2844.jpg
# found for Image HF_3649.jpg!
#
# Duplicate HF_4597.jpg
# found for Image HF_3316.jpg!
#
# Duplicate HF_3265.jpg
# found for Image HF_3817.jpg!
#
# Duplicate HF_3456.jpg
# found for Image HF_3433.jpg!
#
# Duplicate HF_2487.jpg
# found for Image HF_83.jpg!
#
# Duplicate HF_3832.jpg
# found for Image HF_3280.jpg!
#
# Duplicate HF_23.jpg
# found for Image HF_1538.jpg!
#
# Duplicate HF_1193.jpg
# found for Image HF_1447.jpg!
#
# Duplicate HF_320.jpg
# found for Image HF_1244.jpg!
#
# Duplicate HF_3038.jpg
# found for Image HF_4524.jpg!
#
# Duplicate HF_265.jpg
# found for Image HF_1508.jpg!
#
# Duplicate HF_5089.jpg
# found for Image HF_4688.jpg!
#
# Duplicate HF_2695.jpg
# found for Image HF_4024.jpg!
#
# Duplicate HF_4388.jpg
# found for Image HF_3677.jpg!
#
# Duplicate HF_26.jpeg
# found for Image HF_62.jpeg!
#
# Duplicate HF_4235.jpg
# found for Image HF_3451.jpg!
#
# Duplicate HF_2149.jpg
# found for Image HF_174.jpg!
#
# Duplicate HF_4099.jpg
# found for Image HF_2737.jpg!
#
# Duplicate HF_4576.jpg
# found for Image HF_4093.jpg!
#
# Duplicate HF_1300.jpg
# found for Image HF_2539.jpg!
#
# Duplicate HF_3627.jpg
# found for Image HF_5060.jpg!
#
# Duplicate HF_646.jpg
# found for Image HF_2130.jpg!
#
# Duplicate HF_4662.jpg
# found for Image HF_2687.jpg!
#
# Duplicate HF_2585.jpg
# found for Image HF_1216.jpg!
#
# Duplicate HF_4760.jpg
# found for Image HF_3023.jpg!
#
# Duplicate HF_1821.jpg
# found for Image HF_1020.jpg!
#
# Duplicate HF_4326.jpg
# found for Image HF_4677.jpg!
#
# Duplicate HF_1593.jpg
# found for Image HF_384.jpg!
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Streaming output truncated to the last 5000 lines.
# Duplicate HF_2479.jpg
# found for Image HF_457.jpg!
#
# Duplicate HF_4060.jpg
# found for Image HF_4176.jpg!
#
# Duplicate HF_3869.jpg
# found for Image HF_4345.jpg!
#
# Duplicate HF_4405.jpg
# found for Image HF_4930.jpg!
#
# Duplicate HF_743.jpg
# found for Image HF_2601.jpg!
#
# Duplicate HF_1723.jpg
# found for Image HF_75.jpg!
#
# Duplicate HF_3018.jpg
# found for Image HF_4175.jpg!
#
# Duplicate HF_48.png
# found for Image HF_21.png!
#
# Duplicate HF_4433.jpg
# found for Image HF_3542.jpg!
#
# Duplicate HF_4220.jpg
# found for Image HF_3728.jpg!
#
# Duplicate HF_3483.jpg
# found for Image HF_4282.jpg!
#
# Duplicate HF_4815.jpg
# found for Image HF_5120.jpg!
#
# Duplicate HF_4826.jpg
# found for Image HF_5142.jpg!
#
# Duplicate HF_6976.jpg
# found for Image HF_5451.jpg!
#
# Duplicate HF_2008.jpg
# found for Image HF_2187.jpg!
#
# Duplicate HF_1572.jpg
# found for Image HF_759.jpg!
#
# Duplicate HF_1098.jpg
# found for Image HF_2440.jpg!
#
# Duplicate HF_141.jpg
# found for Image HF_2047.jpg!
#
# Duplicate HF_402.jpg
# found for Image HF_1936.jpg!
#
# Duplicate HF_4486.jpg
# found for Image HF_4718.jpg!
#
# Duplicate HF_2634.jpg
# found for Image HF_1769.jpg!
#
# Duplicate HF_3227.jpg
# found for Image HF_4064.jpg!
#
# Duplicate HF_3718.jpg
# found for Image HF_2939.jpg!
#
# Duplicate HF_4581.jpg
# found for Image HF_3756.jpg!
#
# Duplicate HF_1622.jpg
# found for Image HF_2193.jpg!
#
# Duplicate HF_4673.jpg
# found for Image HF_3527.jpg!
#
# Duplicate HF_3952.jpg
# found for Image HF_2883.jpg!
#
# Duplicate HF_4650.jpg
# found for Image HF_3998.jpg!
#
# Duplicate HF_58.jpeg
# found for Image HF_33.jpeg!
#
# Duplicate HF_5131.jpg
# found for Image HF_4817.jpg!
#
# Duplicate HF_2070.jpg
# found for Image HF_2063.jpg!
#
# Duplicate HF_2715.jpg
# found for Image HF_4080.jpg!
#
# Duplicate HF_1553.jpg
# found for Image HF_497.jpg!
#
# Duplicate HF_1420.jpg
# found for Image HF_1780.jpg!
#
# Duplicate HF_46.jpg
# found for Image HF_1018.jpg!
#
# Duplicate HF_5108.jpg
# found for Image HF_4176.jpg!
#
# Duplicate HF_2708.jpg
# found for Image HF_4311.jpg!
#
# Duplicate HF_4370.jpg
# found for Image HF_4694.jpg!
#
# Duplicate HF_3053.jpg
# found for Image HF_4257.jpg!
#
# Duplicate HF_1905.jpg
# found for Image HF_2441.jpg!
#
# Duplicate HF_2942.jpg
# found for Image HF_3955.jpg!
#
# Duplicate HF_870.jpg
# found for Image HF_2045.jpg!
#
# Duplicate HF_3073.jpg
# found for Image HF_3360.jpg!
#
# Duplicate HF_347.jpg
# found for Image HF_1341.jpg!
#
# Duplicate HF_4648.jpg
# found for Image HF_4490.jpg!
#
# Duplicate HF_5072.jpg
# found for Image HF_2760.jpg!
#
# Duplicate HF_601.jpg
# found for Image HF_1980.jpg!
#
# Duplicate HF_2328.jpg
# found for Image HF_1457.jpg!
#
# Duplicate HF_4887.jpg
# found for Image HF_4988.jpg!
#
# Duplicate HF_2756.jpg
# found for Image HF_4691.jpg!
#
# Duplicate HF_303.jpg
# found for Image HF_1518.jpg!
#
# Duplicate HF_67.jpeg
# found for Image HF_78.jpeg!
#
# Duplicate HF_5124.jpg
# found for Image HF_3242.jpg!
#
# Duplicate HF_3094.jpg
# found for Image HF_4177.jpg!
#
# Duplicate HF_1489.jpg
# found for Image HF_1487.jpg!
#
# Duplicate HF_2681.jpg
# found for Image HF_3880.jpg!
#
# Duplicate HF_1745.jpg
# found for Image HF_749.jpg!
#
# Duplicate HF_2871.jpg
# found for Image HF_4922.jpg!
#
# Duplicate HF_2143.jpg
# found for Image HF_2607.jpg!
#
# Duplicate HF_3417.jpg
# found for Image HF_3035.jpg!
#
# Duplicate HF_168.jpg
# found for Image HF_2552.jpg!
#
# Duplicate HF_4269.jpg
# found for Image HF_2671.jpg!
#
# Duplicate HF_4063.jpg
# found for Image HF_3492.jpg!
#
# Duplicate HF_22.jpeg
# found for Image HF_78.jpeg!
#
# Duplicate HF_4725.jpg
# found for Image HF_5175.jpg!
#
# Duplicate HF_1911.jpg
# found for Image HF_975.jpg!
#
# Duplicate HF_5037.jpg
# found for Image HF_3077.jpg!
#
# Duplicate HF_1920.jpg
# found for Image HF_1244.jpg!
#
# Duplicate HF_3332.jpg
# found for Image HF_4856.jpg!
#
# Duplicate HF_400.jpg
# found for Image HF_1447.jpg!
#
# Duplicate HF_304.jpg
# found for Image HF_222.jpg!
#
# Duplicate HF_1212.jpg
# found for Image HF_103.jpg!
#
# Duplicate HF_2807.jpg
# found for Image HF_3372.jpg!
#
# Duplicate HF_4586.jpg
# found for Image HF_3220.jpg!
#
# Duplicate HF_4876.jpg
# found for Image HF_2826.jpg!
#
# Duplicate HF_2021.jpg
# found for Image HF_2356.jpg!
#
# Duplicate HF_2529.jpg
# found for Image HF_535.jpg!
#
# Duplicate HF_3409.jpg
# found for Image HF_3665.jpg!
#
# Duplicate HF_5165.jpg
# found for Image HF_2145.jpg!
#
# Duplicate HF_2340.jpg
# found for Image HF_365.jpg!
#
# Duplicate HF_4951.jpg
# found for Image HF_3410.jpg!
#
# Duplicate HF_58.jpg
# found for Image HF_2147.jpg!
#
# Duplicate HF_4266.jpg
# found for Image HF_2711.jpg!
#
# Duplicate HF_4797.jpg
# found for Image HF_2667.jpg!
#
# Duplicate HF_240.jpg
# found for Image HF_2028.jpg!
#
# Duplicate HF_971.jpg
# found for Image HF_2293.jpg!
#
# Duplicate HF_3030.jpg
# found for Image HF_3397.jpg!
#
# Duplicate HF_3407.jpg
# found for Image HF_4242.jpg!
#
# Duplicate HF_2669.jpg
# found for Image HF_5018.jpg!
#
# Duplicate HF_5100.jpg
# found for Image HF_3670.jpg!
#
# Duplicate HF_3061.jpg
# found for Image HF_4857.jpg!
#
# Duplicate HF_245.jpg
# found for Image HF_2304.jpg!
#
# Duplicate HF_2207.jpg
# found for Image HF_45.jpg!
#
# Duplicate HF_210.jpg
# found for Image HF_1149.jpg!
#
# Duplicate HF_3354.jpg
# found for Image HF_4227.jpg!
#
# Duplicate HF_491.jpg
# found for Image HF_1487.jpg!
#
# Duplicate HF_3296.jpg
# found for Image HF_4985.jpg!
#
# Duplicate HF_3016.jpg
# found for Image HF_4337.jpg!
#
# Duplicate HF_885.jpg
# found for Image HF_1881.jpg!
#
# Duplicate HF_2074.jpg
# found for Image HF_2566.jpg!
#
# Duplicate HF_148.png
# found for Image HF_78.png!
#
# Duplicate HF_771.jpg
# found for Image HF_1771.jpg!
#
# Duplicate HF_899.jpg
# found for Image HF_2046.jpg!
#
# Duplicate HF_5156.jpg
# found for Image HF_3706.jpg!
#
# Duplicate HF_5075.jpg
# found for Image HF_4752.jpg!
#
# Duplicate HF_2625.jpg
# found for Image HF_2068.jpg!
#
# Duplicate HF_3779.jpg
# found for Image HF_5013.jpg!
#
# Duplicate HF_1908.jpg
# found for Image HF_1959.jpg!
#
# Duplicate HF_2791.jpg
# found for Image HF_4227.jpg!
#
# Duplicate HF_1313.jpg
# found for Image HF_1942.jpg!
#
# Duplicate HF_4500.jpg
# found for Image HF_2858.jpg!
#
# Duplicate HF_2515.jpg
# found for Image HF_353.jpg!
#
# Duplicate HF_4547.jpg
# found for Image HF_4085.jpg!
#
# Duplicate HF_75.png
# found for Image HF_110.png!
#
# Duplicate HF_1379.jpg
# found for Image HF_531.jpg!
#
# Duplicate HF_456.jpg
# found for Image HF_1256.jpg!
#
# Duplicate HF_3366.jpg
# found for Image HF_5044.jpg!
#
# Duplicate HF_3761.jpg
# found for Image HF_4254.jpg!
#
# Duplicate HF_2847.jpg
# found for Image HF_3564.jpg!
#
# Duplicate HF_3177.jpg
# found for Image HF_4103.jpg!
#
# Duplicate HF_4341.jpg
# found for Image HF_3615.jpg!
#
# Duplicate HF_3501.jpg
# found for Image HF_3391.jpg!
#
# Duplicate HF_479.jpg
# found for Image HF_2620.jpg!
#
# Duplicate HF_917.jpg
# found for Image HF_1320.jpg!
#
# Duplicate HF_251.jpg
# found for Image HF_1495.jpg!
#
# Duplicate HF_2337.jpg
# found for Image HF_2066.jpg!
#
# Duplicate HF_670.jpg
# found for Image HF_1535.jpg!
#
# Duplicate HF_4791.jpg
# found for Image HF_3866.jpg!
#
# Duplicate HF_2115.jpg
# found for Image HF_1133.jpg!
#
# Duplicate HF_2335.jpg
# found for Image HF_1479.jpg!
#
# Duplicate HF_761.jpg
# found for Image HF_2193.jpg!
#
# Duplicate HF_2960.jpg
# found for Image HF_3614.jpg!
#
# Duplicate HF_2862.jpg
# found for Image HF_4751.jpg!
#
# Duplicate HF_3199.jpg
# found for Image HF_3868.jpg!
#
# Duplicate HF_76.png
# found for Image HF_96.png!
#
# Duplicate HF_2794.jpg
# found for Image HF_3596.jpg!
#
# Duplicate HF_2580.jpg
# found for Image HF_993.jpg!
#
# Duplicate HF_2679.jpg
# found for Image HF_3680.jpg!
#
# Duplicate HF_1706.jpg
# found for Image HF_2620.jpg!
#
# Duplicate HF_1035.jpg
# found for Image HF_1620.jpg!
#
# Duplicate HF_2777.jpg
# found for Image HF_4100.jpg!
#
# Duplicate HF_2547.jpg
# found for Image HF_2063.jpg!
#
# Duplicate HF_1225.jpg
# found for Image HF_1184.jpg!
#
# Duplicate HF_2932.jpg
# found for Image HF_3523.jpg!
#
# Duplicate HF_1378.jpg
# found for Image HF_176.jpg!
#
# Duplicate HF_4160.jpg
# found for Image HF_4779.jpg!
#
# Duplicate HF_123.png
# found for Image HF_135.png!
#
# Duplicate HF_3491.jpg
# found for Image HF_4342.jpg!
#
# Duplicate HF_972.jpg
# found for Image HF_2013.jpg!
#
# Duplicate HF_1862.jpg
# found for Image HF_890.jpg!
#
# Duplicate HF_897.jpg
# found for Image HF_1868.jpg!
#
# Duplicate HF_3100.jpg
# found for Image HF_4040.jpg!
#
# Duplicate HF_5099.jpg
# found for Image HF_4931.jpg!
#
# Duplicate HF_44.jpeg
# found for Image HF_74.jpeg!
#
# Duplicate HF_1528.jpg
# found for Image HF_2563.jpg!
#
# Duplicate HF_4399.jpg
# found for Image HF_3823.jpg!
#
# Duplicate HF_4487.jpg
# found for Image HF_3314.jpg!
#
# Duplicate HF_3848.jpg
# found for Image HF_4414.jpg!
#
# Duplicate HF_23.jpeg
# found for Image HF_78.jpeg!
#
# Duplicate HF_268.jpg
# found for Image HF_2539.jpg!
#
# Duplicate HF_3559.jpg
# found for Image HF_2843.jpg!
#
# Duplicate HF_64.jpg
# found for Image HF_1866.jpg!
#
# Duplicate HF_3026.jpg
# found for Image HF_4242.jpg!
#
# Duplicate HF_2128.jpg
# found for Image HF_592.jpg!
#
# Duplicate HF_776.jpg
# found for Image HF_1216.jpg!
#
# Duplicate HF_13.jpg
# found for Image HF_1020.jpg!
#
# Duplicate HF_4261.jpg
# found for Image HF_3768.jpg!
#
# Duplicate HF_3382.jpg
# found for Image HF_3670.jpg!
#
# Duplicate HF_507.jpg
# found for Image HF_2575.jpg!
#
# Duplicate HF_34.jpg
# found for Image HF_2016.jpg!
#
# Duplicate HF_630.jpg
# found for Image HF_1425.jpg!
#
# Duplicate HF_2241.jpg
# found for Image HF_2193.jpg!
#
# Duplicate HF_1670.jpg
# found for Image HF_2210.jpg!
#
# Duplicate HF_1646.jpg
# found for Image HF_2642.jpg!
#
# Duplicate HF_4335.jpg
# found for Image HF_3998.jpg!
#
# Duplicate HF_1609.jpg
# found for Image HF_1059.jpg!
#
# Duplicate HF_1044.jpg
# found for Image HF_1234.jpg!
#
# Duplicate HF_3924.jpg
# found for Image HF_4441.jpg!
#
# Duplicate HF_2888.jpg
# found for Image HF_3957.jpg!
#
# Duplicate HF_2049.jpg
# found for Image HF_393.jpg!
#
# Duplicate HF_5133.jpg
# found for Image HF_3664.jpg!
#
# Duplicate HF_450.jpg
# found for Image HF_1229.jpg!
#
# Duplicate HF_3584.jpg
# found for Image HF_4408.jpg!
#
# Duplicate HF_2395.jpg
# found for Image HF_2101.jpg!
#
# Duplicate HF_3058.jpg
# found for Image HF_4153.jpg!
#
# Duplicate HF_1607.jpg
# found for Image HF_2336.jpg!
#
# Duplicate HF_4811.jpg
# found for Image HF_5122.jpg!
#
# Duplicate HF_1459.jpg
# found for Image HF_2319.jpg!
#
# Duplicate HF_5090.jpg
# found for Image HF_4470.jpg!
#
# Duplicate HF_4828.jpg
# found for Image HF_4710.jpg!
#
# Duplicate HF_5135.jpg
# found for Image HF_2887.jpg!
#
# Duplicate HF_864.jpg
# found for Image HF_2493.jpg!
#
# Duplicate HF_2394.jpg
# found for Image HF_1303.jpg!
#
# Duplicate HF_1266.jpg
# found for Image HF_459.jpg!
#
# Duplicate HF_2221.jpg
# found for Image HF_543.jpg!
#
# Duplicate HF_274.jpg
# found for Image HF_1850.jpg!
#
# Duplicate HF_879.jpg
# found for Image HF_759.jpg!
#
# Duplicate HF_988.jpg
# found for Image HF_1404.jpg!
#
# Duplicate HF_1043.jpg
# found for Image HF_1137.jpg!
#
# Duplicate HF_5009.jpg
# found for Image HF_2895.jpg!
#
# Duplicate HF_2442.jpg
# found for Image HF_395.jpg!
#
# Duplicate HF_5184.jpg
# found for Image HF_4864.jpg!
#
# Duplicate HF_50.jpg
# found for Image HF_2313.jpg!
#
# Duplicate HF_3388.jpg
# found for Image HF_2929.jpg!
#
# Duplicate HF_4428.jpg
# found for Image HF_5103.jpg!
#
# Duplicate HF_2056.jpg
# found for Image HF_82.jpg!
#
# Duplicate HF_2409.jpg
# found for Image HF_2091.jpg!
#
# Duplicate HF_1472.jpg
# found for Image HF_256.jpg!
#
# Duplicate HF_968.jpg
# found for Image HF_2263.jpg!
#
# Duplicate HF_4097.jpg
# found for Image HF_3115.jpg!
#
# Duplicate HF_133.jpg
# found for Image HF_1915.jpg!
#
# Duplicate HF_2492.jpg
# found for Image HF_1115.jpg!
#
# Duplicate HF_1351.jpg
# found for Image HF_108.jpg!
#
# Duplicate HF_2730.jpg
# found for Image HF_3849.jpg!
#
# Duplicate HF_604.jpg
# found for Image HF_2638.jpg!
#
# Duplicate HF_1761.jpg
# found for Image HF_310.jpg!
#
# Duplicate HF_3080.jpg
# found for Image HF_4054.jpg!
#
# Duplicate HF_1912.jpg
# found for Image HF_701.jpg!
#
# Duplicate HF_2957.jpg
# found for Image HF_4813.jpg!
#
# Duplicate HF_1205.jpg
# found for Image HF_1539.jpg!
#
# %% [markdown]
# ## PART 3: "Fake-Vs-Real-Faces (Hard)" dataset
#
# Dataset Source: ["Fake-Vs-Real-Faces (Hard)" by Hamza Boulahi](https://www.kaggle.com/datasets/hamzaboulahia/hardfakevsrealfaces)
#
# Loads the dataset from Kaggle through the Kaggle API before removing duplicate images and zipping the files to the drive.

# %% [markdown]
# ##### STEP 1: Import the data from Kaggle using Kaggle API

# %% [markdown]
# 1. Load the raw dataset files from Kaggle

# %%
fake_v_hard_path = kagglehub.dataset_download("hamzaboulahia/hardfakevsrealfaces")

print("Path to dataset files:", fake_v_hard_path)
# Out:
# Path to dataset files: /kaggle/input/hardfakevsrealfaces

# %% [markdown]
# ##### STEP 2: Basic File Exploration

# %% [markdown]
# 1. Check what was downloaded from Kaggle

# %%
os.listdir(fake_v_hard_path)
# Out:
# ['fake', 'real', 'data.csv']

# %% [markdown]
# 1. Check Real Images

# %%
real_images_path = fake_v_hard_path + '/real/'
real_image_filenames = os.listdir(real_images_path)
REAL_IMG_EXTENSIONS = get_file_extensions(real_images_path)

print("Number of image files:", len(real_image_filenames))
print("Image file extensions:", REAL_IMG_EXTENSIONS)
# Out:
# Number of image files: 589
# Image file extensions: {'.jpg'}

# %% [markdown]
# 2. Check Fake Images

# %%
fake_images_path = fake_v_hard_path + '/fake/'
fake_image_filenames = os.listdir(fake_images_path)
FAKE_IMG_EXTENSIONS = get_file_extensions(fake_images_path)

print("Number of image files:", len(fake_image_filenames))
print("Image file extensions:", FAKE_IMG_EXTENSIONS)
# Out:
# Number of image files: 700
# Image file extensions: {'.jpg'}

# %% [markdown]
# 3. Check the data.csv file

# %%
pd.read_csv(fake_v_hard_path + "/data.csv")
# Out:
#      images_id label
# 0       real_1  real
# 1      real_10  real
# 2     real_100  real
# 3     real_101  real
# 4     real_102  real
# ...        ...   ...
# 1284   fake_95  fake
# 1285   fake_96  fake
# 1286   fake_97  fake
# 1287   fake_98  fake
# 1288   fake_99  fake
#
# [1289 rows x 2 columns]

# %% [markdown]
# ##### STEP 3: Clean the Data
#
# References:
# 1. ["Deleting duplicated images" by saworz](https://www.kaggle.com/code/saworz/deleting-duplicated-images?scriptVersionId=108951245)

# %% [markdown]
# 1. Check the real images for duplicates

# %%
dr = DuplicateRemover(real_images_path)
dr.find_duplicates()
# Out:
# Finding Duplicates Now!
#
# No Duplicates Found :(

# %% [markdown]
# 2. Check the fake images for duplicates

# %%
dr = DuplicateRemover(fake_images_path)
dr.find_duplicates()
# Out:
# Finding Duplicates Now!
#
# No Duplicates Found :(

# %% [markdown]
# ##### STEP 3: Store the Files in Drive

# %% [markdown]
# 1. Store the fake images and the real images separately as zip files

# %%
zip_files(real_images_path, 'RealImages.zip')
zip_files(fake_images_path, 'FakeImages.zip')
# Out:
# Folder /root/.cache/kagglehub/datasets/hamzaboulahia/hardfakevsrealfaces/versions/1/real/ zipped as RealImages.zip
# Folder /root/.cache/kagglehub/datasets/hamzaboulahia/hardfakevsrealfaces/versions/1/fake/ zipped as FakeImages.zip

# %% [markdown]
# 2. Download the .csv label file

# %%
from google.colab import files
files.download(fake_v_hard_path + '/data.csv')

# %% [markdown]
# ## PART 4: deepfake and real images dataset
#
# Dataset Source: ["deepfake and real images" by Manjil Karki](https://www.kaggle.com/datasets/manjilkarki/deepfake-and-real-images)
#
# Upstream Source: ["OpenForensics: Multi-Face Forgery Detection And Segmentation In-The-Wild Dataset \[V.1.0.0\]" by Trung-Nghia Le, Huy H Nguyen, Junichi Yamagishi, and Isao Echizen](https://zenodo.org/record/5528418#.YpdlS2hBzDd)
#
# Loads the test dataset from Kaggle through the Kaggle API before removing duplicate images and zipping a subset of the files to the drive.

# %% [markdown]
# ##### STEP 1: Import the data from Kaggle using Kaggle API

# %% [markdown]
# 1. Load the raw dataset files from Kaggle

# %%
deepfake_and_real_images_path = kagglehub.dataset_download("manjilkarki/deepfake-and-real-images")

print("Path to dataset files:", deepfake_and_real_images_path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.11), please consider upgrading to the latest version (0.3.12).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/manjilkarki/deepfake-and-real-images?dataset_version_number=1...
# 100%|██████████| 1.68G/1.68G [00:12<00:00, 140MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/manjilkarki/deepfake-and-real-images/versions/1

# %% [markdown]
# ##### STEP 2: Basic File Exploration

# %% [markdown]
# 1. Check what was downloaded from Kaggle

# %%
os.listdir(deepfake_and_real_images_path)
# Out:
# ['Dataset']

# %%
os.listdir(deepfake_and_real_images_path + '/Dataset')
# Out:
# ['Test', 'Train', 'Validation']

# %%
os.listdir(deepfake_and_real_images_path + '/Dataset/Test')
# Out:
# ['Real', 'Fake']

# %%
deepfake_and_real_images_path += '/Dataset/Test'
deepfake_and_real_images_path
# Out:
# '/root/.cache/kagglehub/datasets/manjilkarki/deepfake-and-real-images/versions/1/Dataset/Test'

# %% [markdown]
# 1. Check Real Images

# %%
real_images_path = deepfake_and_real_images_path + '/Real/'
real_image_filenames = os.listdir(real_images_path)
REAL_IMG_EXTENSIONS = get_file_extensions(real_images_path)

print("Number of image files:", len(real_image_filenames))
print("Image file extensions:", REAL_IMG_EXTENSIONS)
# Out:
# Number of image files: 5413
# Image file extensions: {'.jpg'}

# %% [markdown]
# 2. Check Fake Images

# %%
fake_images_path = deepfake_and_real_images_path + '/Fake/'
fake_image_filenames = os.listdir(fake_images_path)
FAKE_IMG_EXTENSIONS = get_file_extensions(fake_images_path)

print("Number of image files:", len(fake_image_filenames))
print("Image file extensions:", FAKE_IMG_EXTENSIONS)
# Out:
# Number of image files: 5492
# Image file extensions: {'.jpg'}

# %% [markdown]
# ##### STEP 3: Clean the Data
#
# References:
# 1. ["Deleting duplicated images" by saworz](https://www.kaggle.com/code/saworz/deleting-duplicated-images?scriptVersionId=108951245)

# %% [markdown]
# 1. Check the real images for duplicates

# %%
dr = DuplicateRemover(real_images_path)
dr.find_duplicates()
# Out:
# Finding Duplicates Now!
#
# Duplicate real_4155.jpg
# found for Image real_937.jpg!
#
# Duplicate real_2303.jpg
# found for Image real_4588.jpg!
#
# Duplicate real_2756.jpg
# found for Image real_1917.jpg!
#
# Duplicate real_4951.jpg
# found for Image real_5241.jpg!
#
# Duplicate real_3549.jpg
# found for Image real_2638.jpg!
#
# Duplicate real_1627.jpg
# found for Image real_4680.jpg!
#
# Duplicate real_3676.jpg
# found for Image real_347.jpg!
#
# Duplicate real_4747.jpg
# found for Image real_2485.jpg!
#
# Duplicate real_2815.jpg
# found for Image real_4284.jpg!
#
# Duplicate real_2634.jpg
# found for Image real_1813.jpg!
#
# Duplicate real_557.jpg
# found for Image real_4519.jpg!
#
# Duplicate real_2441.jpg
# found for Image real_3368.jpg!
#
# Duplicate real_233.jpg
# found for Image real_3583.jpg!
#
# Duplicate real_827.jpg
# found for Image real_2491.jpg!
#
# Duplicate real_3974.jpg
# found for Image real_2387.jpg!
#
# Duplicate real_1763.jpg
# found for Image real_3500.jpg!
#
# Duplicate real_271.jpg
# found for Image real_2730.jpg!
#
# Duplicate real_2698.jpg
# found for Image real_1003.jpg!
#
# Duplicate real_5302.jpg
# found for Image real_3219.jpg!
#
# Duplicate real_636.jpg
# found for Image real_2299.jpg!
#
# Duplicate real_3548.jpg
# found for Image real_2637.jpg!
#
# Duplicate real_1657.jpg
# found for Image real_4706.jpg!
#
# Duplicate real_3543.jpg
# found for Image real_178.jpg!
#
# Duplicate real_2461.jpg
# found for Image real_803.jpg!
#
# Duplicate real_2785.jpg
# found for Image real_4262.jpg!
#
# Duplicate real_1332.jpg
# found for Image real_4476.jpg!
#
# Duplicate real_644.jpg
# found for Image real_3918.jpg!
#
# Duplicate real_2300.jpg
# found for Image real_637.jpg!
#
# Duplicate real_3926.jpg
# found for Image real_3192.jpg!
#
# Duplicate real_3486.jpg
# found for Image real_2549.jpg!
#
# Duplicate real_2633.jpg
# found for Image real_1812.jpg!
#
# Duplicate real_4311.jpg
# found for Image real_2851.jpg!
#
# Duplicate real_2334.jpg
# found for Image real_4623.jpg!
#
# Duplicate real_3635.jpg
# found for Image real_302.jpg!
#
# Duplicate real_2431.jpg
# found for Image real_3991.jpg!
#
# Duplicate real_2292.jpg
# found for Image real_3910.jpg!
#
# Duplicate real_4682.jpg
# found for Image real_1629.jpg!
#
# Duplicate real_2358.jpg
# found for Image real_5024.jpg!
#
# Duplicate real_791.jpg
# found for Image real_4010.jpg!
#
# Duplicate real_1234.jpg
# found for Image real_2888.jpg!
#
# Duplicate real_936.jpg
# found for Image real_4154.jpg!
#
# Duplicate real_3063.jpg
# found for Image real_4498.jpg!
#
# Duplicate real_1595.jpg
# found for Image real_722.jpg!
#
# Duplicate real_3523.jpg
# found for Image real_904.jpg!
#
# Duplicate real_348.jpg
# found for Image real_4903.jpg!
#
# Duplicate real_736.jpg
# found for Image real_3301.jpg!
#
# Duplicate real_458.jpg
# found for Image real_2100.jpg!
#
# Duplicate real_2465.jpg
# found for Image real_4017.jpg!
#
# Duplicate real_2383.jpg
# found for Image real_1601.jpg!
#
# Duplicate real_1010.jpg
# found for Image real_4200.jpg!
#
# Duplicate real_5284.jpg
# found for Image real_2288.jpg!
#
# Duplicate real_829.jpg
# found for Image real_2493.jpg!
#
# Duplicate real_2043.jpg
# found for Image real_408.jpg!
#
# Duplicate real_4764.jpg
# found for Image real_1716.jpg!
#
# Duplicate real_4409.jpg
# found for Image real_457.jpg!
#
# Duplicate real_5305.jpg
# found for Image real_3229.jpg!
#
# Duplicate real_4944.jpg
# found for Image real_3777.jpg!
#
# Duplicate real_1744.jpg
# found for Image real_3458.jpg!
#
# Duplicate real_2466.jpg
# found for Image real_1682.jpg!
#
# Duplicate real_4313.jpg
# found for Image real_1178.jpg!
#
# Duplicate real_3022.jpg
# found for Image real_4473.jpg!
#
# Duplicate real_3609.jpg
# found for Image real_268.jpg!
#
# Duplicate real_1733.jpg
# found for Image real_852.jpg!
#
# Duplicate real_2460.jpg
# found for Image real_802.jpg!
#
# Duplicate real_4681.jpg
# found for Image real_1628.jpg!
#
# Duplicate real_2596.jpg
# found for Image real_3531.jpg!
#
# Duplicate real_294.jpg
# found for Image real_1913.jpg!
#
# Duplicate real_4156.jpg
# found for Image real_938.jpg!
#
# Duplicate real_2620.jpg
# found for Image real_4144.jpg!
#
# Duplicate real_2362.jpg
# found for Image real_704.jpg!
#
# Duplicate real_828.jpg
# found for Image real_2492.jpg!
#
# Duplicate real_634.jpg
# found for Image real_1481.jpg!
#
# Duplicate real_4217.jpg
# found for Image real_276.jpg!
#
# Duplicate real_1884.jpg
# found for Image real_266.jpg!
#
# Duplicate real_4310.jpg
# found for Image real_1172.jpg!
#
# Duplicate real_5357.jpg
# found for Image real_3382.jpg!
#
# Duplicate real_576.jpg
# found for Image real_1415.jpg!
#
# Duplicate real_2170.jpg
# found for Image real_506.jpg!
#
# Duplicate real_1138.jpg
# found for Image real_4295.jpg!
#
# Duplicate real_3220.jpg
# found for Image real_5303.jpg!
#
# Duplicate real_4837.jpg
# found for Image real_148.jpg!
#
# Duplicate real_4609.jpg
# found for Image real_3930.jpg!
#
# Duplicate real_4091.jpg
# found for Image real_895.jpg!
#
# Duplicate real_3675.jpg
# found for Image real_346.jpg!
#
# Duplicate real_4099.jpg
# found for Image real_2563.jpg!
#
# Duplicate real_702.jpg
# found for Image real_2361.jpg!
#
# Duplicate real_1882.jpg
# found for Image real_264.jpg!
#
# Duplicate real_923.jpg
# found for Image real_4131.jpg!
#
# Duplicate real_289.jpg
# found for Image real_1057.jpg!
#
# Duplicate real_4014.jpg
# found for Image real_1678.jpg!
#
# Duplicate real_223.jpg
# found for Image real_2672.jpg!
#
# Duplicate real_3300.jpg
# found for Image real_735.jpg!
#
# Duplicate real_876.jpg
# found for Image real_2537.jpg!
#
# Duplicate real_308.jpg
# found for Image real_1924.jpg!
#
# Duplicate real_1681.jpg
# found for Image real_4017.jpg!
#
# Duplicate real_1953.jpg
# found for Image real_325.jpg!
#
# Duplicate real_4656.jpg
# found for Image real_2371.jpg!
#
# Duplicate real_2508.jpg
# found for Image real_849.jpg!
#
# Duplicate real_638.jpg
# found for Image real_2301.jpg!
#
# Duplicate real_4406.jpg
# found for Image real_52.jpg!
#
# Duplicate real_1247.jpg
# found for Image real_4372.jpg!
#
# real_634.jpg Deleted Succesfully!
# real_4217.jpg Deleted Succesfully!
# real_1884.jpg Deleted Succesfully!
# real_4310.jpg Deleted Succesfully!
# real_5357.jpg Deleted Succesfully!
# real_576.jpg Deleted Succesfully!
# real_2170.jpg Deleted Succesfully!
# real_1138.jpg Deleted Succesfully!
# real_3220.jpg Deleted Succesfully!
# real_4837.jpg Deleted Succesfully!
# real_4609.jpg Deleted Succesfully!
# real_4091.jpg Deleted Succesfully!
# real_3675.jpg Deleted Succesfully!
# real_4099.jpg Deleted Succesfully!
# real_702.jpg Deleted Succesfully!
# real_1882.jpg Deleted Succesfully!
# real_923.jpg Deleted Succesfully!
# real_289.jpg Deleted Succesfully!
# real_4014.jpg Deleted Succesfully!
# real_223.jpg Deleted Succesfully!
# real_3300.jpg Deleted Succesfully!
# real_876.jpg Deleted Succesfully!
# real_308.jpg Deleted Succesfully!
# real_1681.jpg Deleted Succesfully!
# real_1953.jpg Deleted Succesfully!
# real_4656.jpg Deleted Succesfully!
# real_2508.jpg Deleted Succesfully!
# real_638.jpg Deleted Succesfully!
# real_4406.jpg Deleted Succesfully!
# real_1247.jpg Deleted Succesfully!
# real_1205.jpg Deleted Succesfully!
# real_4659.jpg Deleted Succesfully!
# real_1912.jpg Deleted Succesfully!
#
#
# You saved 1 mb of Space!

# %% [markdown]
# 2. Check the fake images for duplicates

# %%
dr = DuplicateRemover(fake_images_path)
dr.find_duplicates()
# Out:
# Finding Duplicates Now!
#
# Duplicate fake_856.jpg
# found for Image fake_3274.jpg!
#
# Duplicate fake_4100.jpg
# found for Image fake_1626.jpg!
#
# Duplicate fake_1516.jpg
# found for Image fake_4005.jpg!
#
# Duplicate fake_4984.jpg
# found for Image fake_2634.jpg!
#
# Duplicate fake_4217.jpg
# found for Image fake_1764.jpg!
#
# Duplicate fake_1514.jpg
# found for Image fake_4003.jpg!
#
# Duplicate fake_731.jpg
# found for Image fake_5389.jpg!
#
# Duplicate fake_5007.jpg
# found for Image fake_2650.jpg!
#
# Duplicate fake_1763.jpg
# found for Image fake_4216.jpg!
#
# Duplicate fake_3499.jpg
# found for Image fake_1102.jpg!
#
# Duplicate fake_5006.jpg
# found for Image fake_2649.jpg!
#
# Duplicate fake_641.jpg
# found for Image fake_5303.jpg!
#
# Duplicate fake_1931.jpg
# found for Image fake_4376.jpg!
#
# Duplicate fake_2503.jpg
# found for Image fake_4852.jpg!
#
# Duplicate fake_3460.jpg
# found for Image fake_2546.jpg!
#
# Duplicate fake_2949.jpg
# found for Image fake_548.jpg!
#
# Duplicate fake_3655.jpg
# found for Image fake_1213.jpg!
#
# Duplicate fake_724.jpg
# found for Image fake_4703.jpg!
#
# Duplicate fake_424.jpg
# found for Image fake_2811.jpg!
#
# Duplicate fake_957.jpg
# found for Image fake_3365.jpg!
#
# Duplicate fake_4386.jpg
# found for Image fake_1938.jpg!
#
# Duplicate fake_4729.jpg
# found for Image fake_2324.jpg!
#
# Duplicate fake_2972.jpg
# found for Image fake_585.jpg!
#
# Duplicate fake_3747.jpg
# found for Image fake_1284.jpg!
#
# Duplicate fake_969.jpg
# found for Image fake_3378.jpg!
#
# Duplicate fake_905.jpg
# found for Image fake_3318.jpg!
#
# Duplicate fake_5154.jpg
# found for Image fake_2849.jpg!
#
# Duplicate fake_255.jpg
# found for Image fake_334.jpg!
#
# Duplicate fake_375.jpg
# found for Image fake_2748.jpg!
#
# Duplicate fake_2859.jpg
# found for Image fake_457.jpg!
#
# Duplicate fake_791.jpg
# found for Image fake_3212.jpg!
#
# Duplicate fake_1285.jpg
# found for Image fake_3748.jpg!
#
# Duplicate fake_3781.jpg
# found for Image fake_1332.jpg!
#
# Duplicate fake_136.jpg
# found for Image fake_1787.jpg!
#
# Duplicate fake_1748.jpg
# found for Image fake_4201.jpg!
#
# Duplicate fake_441.jpg
# found for Image fake_2836.jpg!
#
# Duplicate fake_471.jpg
# found for Image fake_5179.jpg!
#
# Duplicate fake_573.jpg
# found for Image fake_5262.jpg!
#
# Duplicate fake_381.jpg
# found for Image fake_2752.jpg!
#
# Duplicate fake_2999.jpg
# found for Image fake_605.jpg!
#
# Duplicate fake_1710.jpg
# found for Image fake_4165.jpg!
#
# Duplicate fake_2962.jpg
# found for Image fake_570.jpg!
#
# Duplicate fake_391.jpg
# found for Image fake_2772.jpg!
#
# Duplicate fake_4004.jpg
# found for Image fake_1515.jpg!
#
# Duplicate fake_5447.jpg
# found for Image fake_3232.jpg!
#
# Duplicate fake_4448.jpg
# found for Image fake_2016.jpg!
#
# Duplicate fake_4714.jpg
# found for Image fake_2310.jpg!
#
# Duplicate fake_2648.jpg
# found for Image fake_5005.jpg!
#
# Duplicate fake_4365.jpg
# found for Image fake_1911.jpg!
#
# Duplicate fake_240.jpg
# found for Image fake_322.jpg!
#
# Duplicate fake_3749.jpg
# found for Image fake_1286.jpg!
#
# Duplicate fake_5081.jpg
# found for Image fake_2721.jpg!
#
# Do you want to delete these 52 Images? Press Y or N:  Y
# fake_856.jpg Deleted Succesfully!
# fake_4100.jpg Deleted Succesfully!
# fake_1516.jpg Deleted Succesfully!
# fake_4984.jpg Deleted Succesfully!
# fake_4217.jpg Deleted Succesfully!
# fake_1514.jpg Deleted Succesfully!
# fake_731.jpg Deleted Succesfully!
# fake_5007.jpg Deleted Succesfully!
# fake_1763.jpg Deleted Succesfully!
# fake_3499.jpg Deleted Succesfully!
# fake_5006.jpg Deleted Succesfully!
# fake_641.jpg Deleted Succesfully!
# fake_1931.jpg Deleted Succesfully!
# fake_2503.jpg Deleted Succesfully!
# fake_3460.jpg Deleted Succesfully!
# fake_2949.jpg Deleted Succesfully!
# fake_3655.jpg Deleted Succesfully!
# fake_724.jpg Deleted Succesfully!
# fake_424.jpg Deleted Succesfully!
# fake_957.jpg Deleted Succesfully!
# fake_4386.jpg Deleted Succesfully!
# fake_4729.jpg Deleted Succesfully!
# fake_2972.jpg Deleted Succesfully!
# fake_3747.jpg Deleted Succesfully!
# fake_969.jpg Deleted Succesfully!
# fake_905.jpg Deleted Succesfully!
# fake_5154.jpg Deleted Succesfully!
# fake_255.jpg Deleted Succesfully!
# fake_375.jpg Deleted Succesfully!
# fake_2859.jpg Deleted Succesfully!
# fake_791.jpg Deleted Succesfully!
# fake_1285.jpg Deleted Succesfully!
# fake_3781.jpg Deleted Succesfully!
# fake_136.jpg Deleted Succesfully!
# fake_1748.jpg Deleted Succesfully!
# fake_441.jpg Deleted Succesfully!
# fake_471.jpg Deleted Succesfully!
# fake_573.jpg Deleted Succesfully!
# fake_381.jpg Deleted Succesfully!
# fake_2999.jpg Deleted Succesfully!
# fake_1710.jpg Deleted Succesfully!
# fake_2962.jpg Deleted Succesfully!
# fake_391.jpg Deleted Succesfully!
# fake_4004.jpg Deleted Succesfully!
# fake_5447.jpg Deleted Succesfully!
# fake_4448.jpg Deleted Succesfully!
# fake_4714.jpg Deleted Succesfully!
# fake_2648.jpg Deleted Succesfully!
# fake_4365.jpg Deleted Succesfully!
# fake_240.jpg Deleted Succesfully!
# fake_3749.jpg Deleted Succesfully!
# fake_5081.jpg Deleted Succesfully!
#
#
# You saved 1 mb of Space!

# %% [markdown]
# ##### STEP 4: Create a .csv file labeling fake and real images

# %% [markdown]
# 1. Get the updated files for real and fake images.

# %%
real_image_filenames = os.listdir(real_images_path)
fake_image_filenames = os.listdir(fake_images_path)

print("Number of image files:", len(real_image_filenames))
print("Number of image files:", len(fake_image_filenames))
# Out:
# Number of image files: 5309
# Number of image files: 5440

# %% [markdown]
# 2. Take a subset of 258 total images for a test dataset, 129 from the fake folder and 129 from the real folder.

# %%
realSubset = real_image_filenames[:129]
fakeSubset = fake_image_filenames[:129]

# %% [markdown]
# 3. Create the dataframe labeling the fake images as fake and the real images as real.

# %%
zero_labels = [0 for _ in range(len(fakeSubset))]
one_labels = [1 for _ in range(len(realSubset))]
filenames = pd.DataFrame({"images_id": fakeSubset + realSubset, "label": zero_labels + one_labels})
filenames
# Out:
#          images_id  label
# 0    fake_5234.jpg      0
# 1     fake_366.jpg      0
# 2    fake_4479.jpg      0
# 3    fake_2599.jpg      0
# 4     fake_577.jpg      0
# ..             ...    ...
# 253  real_4180.jpg      1
# 254  real_3319.jpg      1
# 255  real_4011.jpg      1
# 256  real_4527.jpg      1
# 257  real_2145.jpg      1
#
# [258 rows x 2 columns]

# %% [markdown]
# 4. Save the label of the test data to the drive.

# %%
filenames.to_csv(project_folder + "/test_data.csv", index=False)

# %% [markdown]
# 4. Confirm the dataset labeling was saved.

# %%
pd.read_csv(project_folder + "/test_data.csv")
# Out:
#          images_id  label
# 0    fake_5234.jpg      0
# 1     fake_366.jpg      0
# 2    fake_4479.jpg      0
# 3    fake_2599.jpg      0
# 4     fake_577.jpg      0
# ..             ...    ...
# 253  real_4180.jpg      1
# 254  real_3319.jpg      1
# 255  real_4011.jpg      1
# 256  real_4527.jpg      1
# 257  real_2145.jpg      1
#
# [258 rows x 2 columns]

# %% [markdown]
# ##### STEP 3: Store the Files in Drive

# %% [markdown]
# 1. Store the fake images and the real images separately as zip files

# %%
zip_files(real_images_path, project_folder + '/Test_RealImages.zip', whitelist=realSubset)
zip_files(fake_images_path, project_folder + '/Test_FakeImages.zip', whitelist=fakeSubset)
# Out:
# 129 files from folder /root/.cache/kagglehub/datasets/manjilkarki/deepfake-and-real-images/versions/1/Dataset/Test/Real/ have been zipped as drive/MyDrive/CS4644_FinalProject/Test_RealImages.zip
# 129 files from folder /root/.cache/kagglehub/datasets/manjilkarki/deepfake-and-real-images/versions/1/Dataset/Test/Fake/ have been zipped as drive/MyDrive/CS4644_FinalProject/Test_FakeImages.zip

# %% [markdown]
# ## Part 5: Test Load Datasets from Drive .zip Files

# %% [markdown]
# ##### STEP 1: Load "Human Faces" Dataset

# %%
zip_to_colab(project_folder + '/HumanFacesCleaned.zip', "HumanFacesImages")
HUMANFACES_IMAGE_EXTENSIONS = {'.JPG', '.jpeg', '.jpg', '.png'}
# Out:
# Files from drive/MyDrive/CS4644_FinalProject/HumanFacesCleaned.zip extracted to: /content/HumanFacesImages/
# Number of files extracted: 3273

# %% [markdown]
# ##### STEP 2: Load "Fake-Vs-Real-Faces (Hard)" Dataset

# %%
zip_to_colab(project_folder + '/RealImages.zip', 'TrainValRealImages')
zip_to_colab(project_folder + '/FakeImages.zip', 'TrainValFakeImages')
FAKEVREAL_IMAGE_EXTENSIONS = {'.jpg'}
# Out:
# Files from drive/MyDrive/CS4644_FinalProject/RealImages.zip extracted to: /content/TrainValRealImages/
# Number of files extracted: 589
# Files from drive/MyDrive/CS4644_FinalProject/FakeImages.zip extracted to: /content/TrainValFakeImages/
# Number of files extracted: 700

# %% [markdown]
# ##### STEP 3: Load "deepfake and real images" Dataset

# %%
zip_to_colab(project_folder + '/Test_RealImages.zip', 'TestRealImages')
zip_to_colab(project_folder + '/Test_FakeImages.zip', 'TestFakeImages')
FAKEVREAL_IMAGE_EXTENSIONS = {'.jpg'}
# Out:
# Files from drive/MyDrive/CS4644_FinalProject/Test_RealImages.zip extracted to: /content/TestRealImages/
# Number of files extracted: 129
# Files from drive/MyDrive/CS4644_FinalProject/Test_FakeImages.zip extracted to: /content/TestFakeImages/
# Number of files extracted: 129

# %% [markdown]
# ##### STEP 4: Check files

# %%
os.listdir()
# Out:
# ['.config',
#  'TrainValFakeImages',
#  'drive',
#  'TestRealImages',
#  'TestFakeImages',
#  'Test_RealImages.zip',
#  'TrainValRealImages',
#  'HumanFacesImages',
#  'Test_FakeImages.zip',
#  'sample_data']

# %%
print("HumanFacesImages Extensions:", get_file_extensions('/content/HumanFacesImages'))
print("TrainValRealImages Extensions:", get_file_extensions('/content/TrainValRealImages'))
print("TrainValFakeImages Extensions:", get_file_extensions('/content/TrainValFakeImages'))
print("TestFakeImages Extensions:", get_file_extensions('/content/TestFakeImages'))
print("TestRealImages Extensions:", get_file_extensions('/content/TestFakeImages'))
# Out:
# HumanFacesImages Extensions: {'.jpeg', '.jpg', '.png', '.JPG'}
# TrainValRealImages Extensions: {'.jpg'}
# TrainValFakeImages Extensions: {'.jpg'}
# TestFakeImages Extensions: {'.jpg'}
# TestRealImages Extensions: {'.jpg'}
